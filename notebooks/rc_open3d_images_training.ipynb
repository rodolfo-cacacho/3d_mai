# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import copy
import os
import re
import random

# %%
def get_subdirectories(folder_path):
    subdirectories = []
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            subdirectories.append(item)
    return subdirectories

def get_files_in_subdirectories(folder_path, file_extension='', file_contains=''):
    files = []
    for root, directories, filenames in os.walk(folder_path):
        for filename in filenames:
            if file_extension == '' and file_contains == '':
                files.append(os.path.join(root, filename))
            elif file_extension != '' and file_contains == '':
                if filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
            elif file_extension == '' and file_contains != '':
                if file_contains in filename:
                    files.append(os.path.join(root, filename))
            else:
                if file_contains in filename and filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
    return files


def extract_string(filename,format = 'stl'):
    pattern = r'\/([^/]+)\.'+format+'$'
    match = re.search(pattern, filename)
    if match:
        return match.group(1)
    else:
        return None
    
# Defining a function to convert degrees to radians.
def deg2rad(deg):
    return deg * np.pi/180

def get_rotated_pcd(pcd, x_theta, y_theta, z_theta):
    pcd_rotated = copy.deepcopy(pcd)
    R = pcd_rotated.get_rotation_matrix_from_axis_angle([x_theta, y_theta, z_theta])
    pcd_rotated.rotate(R, center=(0, 0, 0))
    return pcd_rotated

def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
        return False
    else:
        print(f"Folder already exists: {folder_path}")
        return True

def delete_file(file_path):
    try:
        os.remove(file_path)
        # print(f"File '{file_path}' deleted successfully.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
    except PermissionError:
        print(f"Permission denied: unable to delete file '{file_path}'.")
    except Exception as e:
        print(f"An error occurred while deleting the file: {e}")

def create_binary_list(n, percentage_of_ones):
    if percentage_of_ones < 0 or percentage_of_ones > 100:
        raise ValueError("Percentage_of_ones must be between 0 and 100")

    num_ones = int(n * (percentage_of_ones / 100))
    num_zeros = n - num_ones

    binary_list = [1] * num_ones + [0] * num_zeros
    random.shuffle(binary_list)

    return binary_list

# %%
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
data_path = parent_dir+'/data/'
cad_path = data_path + 'cad-models/'
print(cad_path)
file_extension = '.stl'
path_save = data_path+'train/imagesO/'
print(path_save)
files = get_files_in_subdirectories(cad_path,file_extension)

exists = create_folder_if_not_exists(path_save)
if exists:
    images_del = get_files_in_subdirectories(path_save,'jpg')
    for imdel in images_del:
        delete_file(imdel)

for i_file in files:

    print("Testing IO for meshes ...")
    name_part = extract_string(i_file)
    print(name_part)
    
    mesh = o3d.io.read_triangle_mesh(i_file)
    mesh.compute_vertex_normals()
    print(mesh)

    # Create a material with a different color (you can customize this)
    material = o3d.visualization.Material()
    print(material)
    # material.base_color = (1.0, 0.0, 0.0)  # Red color

    # Defining the steps and range of angle values by which to rotate the point cloud.
    theta_range = np.linspace(-180, 180, 5)
    zoom_range  = np.linspace(1.8,3,3)

    # Counting the number of sequential operations.
    view_counter = 1
    total_views = theta_range.shape[0] ** 3

    i = 0
    j = 0
    k = 0
    l = 0
    # Looping through the angle values defined above for each axis.
    for x_theta_deg in theta_range:
        j = 0
        for y_theta_deg in theta_range:
            i = 0
            for z_theta_deg in theta_range:
                l=0
                for l_zoom in zoom_range:
                        
                    print(f"Taking image {view_counter} of {total_views}.")

                    # Rotating the point cloud by the given angle values.
                    x_theta = deg2rad(x_theta_deg)
                    y_theta = deg2rad(y_theta_deg)
                    z_theta = deg2rad(z_theta_deg)
                    pcd_rotated = get_rotated_pcd(mesh, x_theta, y_theta, z_theta)

                    # draw_geoms_list = [pcd_rotated]

                    vis = o3d.visualization.Visualizer()
                    vis.create_window(visible=False)

                    # Capture the depth and color images
                    # depth_image = vis.capture_depth_float_buffer()
                    # color_image = vis.capture_screen_float_buffer()

                    # print(depth_image)
                    # # Get the size of the images (width and height)
                    # depth_width, depth_height = depth_image.shape[1], depth_image.shape[0]
                    # color_width, color_height = color_image.shape[1], color_image.shape[0]

                    # print(f"Depth Image Size: {depth_width} x {depth_height}")
                    # print(f"Color Image Size: {color_width} x {color_height}")

                    # vis.add_geometry(mesh)
                    vis.add_geometry(pcd_rotated)
                    # pcd_rotated.translate((-20, 10, 0))  # Adjust the translation values as needed

                    # vis.get_view_control().translate(50, 100, 0)

                    # pcd_rotated.material = material  # Apply the custom material


                    # R = mesh.get_rotation_matrix_from_xyz((angle_vector[i],angle_vector[j],angle_vector[k]))
                    # mesh.rotate(R, center=(0, 0, 0))
                    vis.get_view_control().set_zoom(l_zoom)  # Adjust the zoom factor (0.5 zooms out, 2.0 zooms in)

                    vis.poll_events()
                    vis.update_renderer()
                    #vis.reset_view_point()
                    name_ijk = str(i)+'_'+str(j)+'_'+str(k)+'_'+str(l)
                    vis.capture_screen_image(filename = path_save+'img_ '+name_part+'_ '+name_ijk+'.jpg')

                    # o3d.visualization.draw_geometries(draw_geoms_list)
                    view_counter += 1
                    l +=1
                i +=1
            j +=1
        k+=1

    vis.destroy_window()
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/cad-models/
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/imagesO/
# Created folder: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/imagesO/
# Testing IO for meshes ...
# 10_00_0125_0084a_v4a
# TriangleMesh with 444 points and 296 triangles.
# <open3d.cpu.pybind.visualization.Material object at 0x7f8deb238270>
# Taking image 1 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 2 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 3 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 4 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 5 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 6 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 7 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 8 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 9 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 10 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 11 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 12 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 13 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 14 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 15 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 16 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 17 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 18 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 19 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 20 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 21 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 22 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 23 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 24 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 25 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 26 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 27 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 28 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 29 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 30 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 31 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 32 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 33 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 34 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 35 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 36 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 37 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 38 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 39 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 40 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 41 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 42 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 43 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 44 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 45 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 46 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 47 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 48 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 49 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 50 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 51 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 52 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 53 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 54 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 55 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 56 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 57 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 58 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 59 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 60 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 61 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 62 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 63 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 64 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 65 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 66 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 67 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 68 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 69 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 70 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 71 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 72 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 73 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 74 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 75 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 76 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 77 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 78 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 79 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 80 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 81 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 82 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 83 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 84 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 85 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 86 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 87 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 88 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 89 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 90 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 91 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 92 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 93 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 94 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 95 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 96 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 97 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 98 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 99 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 100 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 101 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 102 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 103 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 104 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 105 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 106 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 107 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 108 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 109 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 110 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 111 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 112 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 113 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 114 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 115 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 116 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 117 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 118 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 119 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 120 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 121 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 122 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 123 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 124 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 125 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 126 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 127 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 128 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 129 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 130 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 131 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 132 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 133 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 134 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 135 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 136 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 137 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 138 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 139 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 140 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 141 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 142 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 143 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 144 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 145 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 146 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 147 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 148 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 149 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 150 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 151 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 152 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 153 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 154 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 155 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 156 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 157 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 158 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 159 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 160 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 161 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 162 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 163 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 164 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 165 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 166 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 167 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 168 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 169 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 170 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 171 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 172 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 173 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 174 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 175 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 176 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 177 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 178 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 179 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 180 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 181 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 182 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 183 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 184 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 185 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 186 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 187 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 188 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 189 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 190 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 191 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 192 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 193 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 194 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 195 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 196 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 197 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 198 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 199 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 200 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 201 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 202 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 203 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 204 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 205 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 206 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 207 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 208 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 209 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 210 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 211 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 212 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 213 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 214 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 215 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 216 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 217 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 218 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 219 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 220 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 221 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 222 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 223 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 224 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 225 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 226 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 227 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 228 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 229 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 230 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 231 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 232 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 233 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 234 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 235 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 236 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 237 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 238 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 239 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 240 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 241 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 242 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 243 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 244 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 245 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 246 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 247 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 248 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 249 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 250 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 251 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 252 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 253 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 254 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 255 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 256 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 257 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 258 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 259 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 260 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 261 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 262 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 263 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 264 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 265 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 266 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 267 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 268 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 269 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 270 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 271 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 272 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 273 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 274 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 275 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 276 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 277 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 278 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 279 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 280 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 281 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 282 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 283 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 284 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 285 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 286 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 287 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 288 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 289 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 290 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 291 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 292 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 293 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 294 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 295 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 296 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 297 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 298 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 299 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 300 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 301 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 302 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 303 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 304 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 305 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 306 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 307 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 308 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 309 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 310 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 311 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 312 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 313 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 314 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 315 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 316 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 317 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 318 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 319 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 320 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 321 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 322 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 323 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 324 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 325 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 326 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 327 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 328 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 329 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 330 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 331 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 332 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 333 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 334 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 335 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 336 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 337 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 338 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 339 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 340 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 341 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 342 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 343 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 344 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 345 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 346 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 347 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 348 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 349 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 350 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 351 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 352 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 353 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 354 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 355 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 356 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 357 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 358 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 359 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 360 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 361 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 362 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 363 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 364 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 365 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 366 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 367 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 368 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 369 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 370 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 371 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 372 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 373 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 374 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 375 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Testing IO for meshes ...
# dst4
# TriangleMesh with 1016 points and 472 triangles.
# <open3d.cpu.pybind.visualization.Material object at 0x7f8deb223970>
# Taking image 1 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 2 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 3 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 4 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 5 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 6 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 7 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 8 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 9 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 10 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 11 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 12 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 13 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 14 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 15 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 16 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 17 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 18 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 19 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 20 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 21 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 22 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 23 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 24 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 25 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 26 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 27 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 28 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 29 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 30 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 31 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 32 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 33 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 34 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 35 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 36 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 37 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 38 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 39 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 40 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 41 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 42 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 43 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 44 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 45 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 46 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 47 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 48 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 49 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 50 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 51 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 52 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 53 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 54 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 55 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 56 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 57 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 58 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 59 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 60 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 61 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 62 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 63 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 64 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 65 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 66 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 67 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 68 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 69 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 70 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 71 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 72 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 73 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 74 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 75 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 76 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 77 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 78 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 79 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 80 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 81 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 82 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 83 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 84 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 85 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 86 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 87 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 88 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 89 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 90 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 91 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 92 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 93 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 94 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 95 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 96 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 97 of 125.
# ...
# Taking image 218 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 219 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 220 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 221 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 222 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 223 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 224 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 225 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 226 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 227 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 228 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 229 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 230 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 231 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 232 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 233 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 234 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 235 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 236 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 237 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 238 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 239 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 240 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 241 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 242 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 243 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 244 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 245 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 246 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 247 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 248 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 249 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 250 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 251 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 252 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 253 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 254 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 255 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 256 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 257 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 258 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 259 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 260 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 261 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 262 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 263 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 264 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 265 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 266 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 267 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 268 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 269 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 270 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 271 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 272 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 273 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 274 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 275 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 276 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 277 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 278 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 279 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 280 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 281 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 282 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 283 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 284 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 285 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 286 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 287 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 288 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 289 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 290 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 291 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 292 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 293 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 294 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 295 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 296 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 297 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 298 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 299 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 300 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 301 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 302 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 303 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 304 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 305 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 306 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 307 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 308 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 309 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 310 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 311 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 312 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 313 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 314 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 315 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 316 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 317 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 318 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 319 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 320 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 321 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 322 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 323 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 324 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 325 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 326 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 327 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 328 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 329 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 330 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 331 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 332 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 333 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 334 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 335 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 336 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 337 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 338 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 339 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 340 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 341 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 342 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 343 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 344 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 345 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 346 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 347 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 348 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 349 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 350 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 351 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 352 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 353 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 354 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 355 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 356 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 357 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 358 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 359 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 360 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 361 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 362 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 363 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 364 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 365 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 366 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 367 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 368 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 369 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 370 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 371 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 372 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 373 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 374 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 375 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
data_path = parent_dir+'/data/'
cad_path = data_path + 'cad-models/'
print(cad_path)
file_extension = '.stl'
path_imgs = data_path+'train/imagesO/'
path_save = path_imgs.replace('imagesO','images')
path_val_save = path_save.replace('train','val')
labels_save = data_path+'train/labels/'
labels_val_save = data_path+'val/labels/'
path_save_bb = data_path+'train/images_wbb/'
print(path_save)
files = get_files_in_subdirectories(cad_path,file_extension)
val_save = ''

exists_save = create_folder_if_not_exists(path_save)
if exists_save:
    images_del = get_files_in_subdirectories(path_save,'jpg')
    for imdel in images_del:
        delete_file(imdel)
exists_lb = create_folder_if_not_exists(labels_save)
if exists_lb:
    images_del = get_files_in_subdirectories(labels_save,'txt')
    for imdel in images_del:
        delete_file(imdel)
exists_wbb = create_folder_if_not_exists(path_save_bb)
if exists_wbb:
    images_del = get_files_in_subdirectories(path_save_bb,'jpg')
    for imdel in images_del:
        delete_file(imdel)
exists_ival = create_folder_if_not_exists(path_val_save)
if exists_ival:
    images_del = get_files_in_subdirectories(path_val_save,'jpg')
    for imdel in images_del:
        delete_file(imdel)
exists_l_val = create_folder_if_not_exists(labels_val_save)
if exists_l_val:
    images_del = get_files_in_subdirectories(labels_val_save,'txt')
    for imdel in images_del:
        delete_file(imdel)
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/cad-models/
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/labels/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images_wbb/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/labels/

# %%
import cv2
images_move = get_files_in_subdirectories(path_imgs,'.jpg')
test_list = create_binary_list(len(images_move), 20)

unique_classes = []

for index, jpg in enumerate(images_move):
    # Load the image
    image = cv2.imread(jpg)

    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Perform edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours in the edge-detected image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Find the convex hull of the contours
    convex_hull = cv2.convexHull(np.vstack(contours))

    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Calculate the bounding box of the convex hull
    x, y, w, h = cv2.boundingRect(convex_hull)

    x1 = x
    y1 = y
    x2 = x + w
    y2 = y + h
    w_reduce = 1200
    h_reduce = 550
    # Calculate the maximum x and y coordinates for the new location
    max_x = image.shape[1] - w - int(w_reduce/2)
    max_y = image.shape[0] - h - int(h_reduce/2)

    # Generate random x and y coordinates for the new location
    new_x = np.random.randint(int(w_reduce/2), max_x + 1)
    new_y = np.random.randint(int(h_reduce/2), max_y + 1)

    # Extract the object
    object_region = image[y1:y2, x1:x2].copy()

    # Paste the object into the new random location
    image[y1:y2, x1:x2] = [255, 255, 255]
    image[new_y:new_y+h, new_x:new_x+w] = object_region

    # Save the edited image
    if test_list[index] == 0:
        jpg_saving_path = jpg.replace("imagesO", "images")
        cv2.imwrite(jpg_saving_path, image)
    else:
        jpg_saving_path = jpg.replace("imagesO", "images")
        jpg_saving_path = jpg_saving_path.replace("train", "val")
        # print(jpg_saving_path)
        cv2.imwrite(jpg_saving_path, image)
    
    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Draw the bounding box on the result image
    cv2.rectangle(result_image, (new_x, new_y), (new_x + w, new_y + h), (0, 255, 0), 2)
    bounding_box_saving_path = jpg.replace("imagesO", "images_wbb")
    cv2.imwrite(bounding_box_saving_path, result_image)

    center_x = new_x + (w) / 2
    center_y = new_y + (h) / 2
    relative_width = (w) / image.shape[1]
    #print(relative_width)
    relative_height = (h) / image.shape[0]
    #print(relative_height)
    relative_center_x= center_x / image.shape[1]
    relative_center_y= center_y / image.shape[0]

    # Open a file for writing the results
    filename = jpg.split('/')[-1].split('.')[0]
    classname = filename.split('_ ')[1]
    if classname not in unique_classes:
        unique_classes.append(classname)
    encoded_class = unique_classes.index(classname)
    if test_list[index] == 0:
        with open(labels_save + filename + '.txt', 'w') as file:
            file.write(f"{encoded_class} {relative_center_x:.5f} {relative_center_y:.5f} {relative_width:.5f} {relative_height:.5f}")
    else:
        with open(labels_save.replace('train','val') + filename + '.txt', 'w') as file:
            file.write(f"{encoded_class} {relative_center_x:.5f} {relative_center_y:.5f} {relative_width:.5f} {relative_height:.5f}")
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_4_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_4_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_0_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_3_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_1_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_3_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_3_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_1_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_1_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_4_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_4_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_0_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_2_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_0_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_4_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_2_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_2_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_3_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_4_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_2_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_0_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_0_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_4_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_1_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_1_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_1_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_2_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_2_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_4_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_4_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_0_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_4_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_0_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_2_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_2_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_4_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_1_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_4_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_4_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_4_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_2_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_2_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_4_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_4_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_3_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_4_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_1_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_4_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_4_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_0_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_3_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_2_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_4_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_4_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_3_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_0_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_1_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_3_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_4_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_1_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_3_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_4_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_1_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_1_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_2_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_2_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_1_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_4_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_4_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_4_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_3_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_1_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_4_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_0_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_0_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_2_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_1_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_1_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_4_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_2_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_3_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_1_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_4_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_0_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_1_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_0_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_0_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_1_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_1_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_1_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_3_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_3_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_2_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_2_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_0_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_4_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_1_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_4_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_0_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_4_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_4_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_2_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_0_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_3_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_2_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_3_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_3_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_1_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_3_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_2_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_4_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_2_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_1_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_3_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_0_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_2_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_2_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_1_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_2_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_2_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_3_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_4_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_4_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_2_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_2_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_4_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_4_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_1_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_1_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_2_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_0_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_0_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_0_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_3_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_1_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_2_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_4_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_1_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_3_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_1_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_1_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_2_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_1_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_1_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_0_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_2_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_3_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_2_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 0_4_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 1_4_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_2_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_3_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_1_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_2_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_3_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_0_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_3_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_1_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_0_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_2_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_3_4_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_3_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_3_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_4_2_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 0_4_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_1_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_3_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_0_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_3_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_1_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 3_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_2_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_3_3_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_0_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_1_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 2_1_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_3_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_4_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_2_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_1_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_0_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_1_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 2_2_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_2_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_1_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_0_4_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 4_2_1_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_0_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_0_3_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_0_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_0_1_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 4_0_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 0_4_3_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 2_0_0_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 3_3_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 0_4_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 3_3_0_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ dst4_ 3_2_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 4_3_1_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_0_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 2_0_2_0.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x20_ 1_4_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_1_2_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 210216-4x10_ 1_4_4_1.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 1_4_0_2.jpg
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/val/images/img_ 10_00_0125_0084a_v4a_ 4_2_1_0.jpg

# %%
sum(test_list)
# Out:
# 300
