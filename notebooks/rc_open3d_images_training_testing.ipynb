# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import copy
import os
import re

# %%
o3d.__version__
# Out:
# '0.16.1'

# %%
def get_subdirectories(folder_path):
    subdirectories = []
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            subdirectories.append(item)
    return subdirectories

def get_files_in_subdirectories(folder_path, file_extension='', file_contains=''):
    files = []
    for root, directories, filenames in os.walk(folder_path):
        for filename in filenames:
            if file_extension == '' and file_contains == '':
                files.append(os.path.join(root, filename))
            elif file_extension != '' and file_contains == '':
                if filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
            elif file_extension == '' and file_contains != '':
                if file_contains in filename:
                    files.append(os.path.join(root, filename))
            else:
                if file_contains in filename and filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
    return files


def extract_string(filename,format = 'stl'):
    pattern = r'\/([^/]+)\.'+format+'$'
    match = re.search(pattern, filename)
    if match:
        return match.group(1)
    else:
        return None
    
# Defining a function to convert degrees to radians.
def deg2rad(deg):
    return deg * np.pi/180

def get_rotated_pcd(pcd, x_theta, y_theta, z_theta):
    pcd_rotated = copy.deepcopy(pcd)
    R = pcd_rotated.get_rotation_matrix_from_axis_angle([x_theta, y_theta, z_theta])
    pcd_rotated.rotate(R, center=(0, 0, 0))
    return pcd_rotated

def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
        return False
    else:
        print(f"Folder already exists: {folder_path}")
        return True

def delete_file(file_path):
    try:
        os.remove(file_path)
        # print(f"File '{file_path}' deleted successfully.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
    except PermissionError:
        print(f"Permission denied: unable to delete file '{file_path}'.")
    except Exception as e:
        print(f"An error occurred while deleting the file: {e}")

# %%
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
data_path = parent_dir+'/data/'
cad_path = data_path + 'cad-models/'
print(cad_path)
file_extension = '.stl'
path_save = data_path+'train/images3/'
print(path_save)
files = get_files_in_subdirectories(cad_path,file_extension)

exists = create_folder_if_not_exists(path_save)
if exists:
    images_del = get_files_in_subdirectories(path_save,'jpg')
    for imdel in images_del:
        delete_file(imdel)

for i_file in files:

    print("Testing IO for meshes ...")
    name_part = extract_string(i_file)
    print(name_part)
    
    mesh = o3d.io.read_triangle_mesh(i_file)
    mesh.compute_vertex_normals()
    print(mesh)

    # Create a material with a different color (you can customize this)
    material = o3d.visualization.Material()
    print(material)
    # material.base_color = (1.0, 0.0, 0.0)  # Red color

    # Defining the steps and range of angle values by which to rotate the point cloud.
    theta_range = np.linspace(-180, 180, 6)
    zoom_range  = np.linspace(1.2,7.5,4)

    # Counting the number of sequential operations.
    view_counter = 1
    total_views = theta_range.shape[0] ** 3

    i = 0
    j = 0
    k = 0
    l = 0
    # Looping through the angle values defined above for each axis.
    for x_theta_deg in theta_range:
        j = 0
        for y_theta_deg in theta_range:
            i = 0
            for z_theta_deg in theta_range:
                l=0
                for l_zoom in zoom_range:
                        
                    print(f"Taking image {view_counter} of {total_views}.")

                    # Rotating the point cloud by the given angle values.
                    x_theta = deg2rad(x_theta_deg)
                    y_theta = deg2rad(y_theta_deg)
                    z_theta = deg2rad(z_theta_deg)
                    pcd_rotated = get_rotated_pcd(mesh, x_theta, y_theta, z_theta)

                    # draw_geoms_list = [pcd_rotated]

                    vis = o3d.visualization.Visualizer()
                    vis.create_window(visible=False)

                    # Capture the depth and color images
                    # depth_image = vis.capture_depth_float_buffer()
                    # color_image = vis.capture_screen_float_buffer()

                    # print(depth_image)
                    # # Get the size of the images (width and height)
                    # depth_width, depth_height = depth_image.shape[1], depth_image.shape[0]
                    # color_width, color_height = color_image.shape[1], color_image.shape[0]

                    # print(f"Depth Image Size: {depth_width} x {depth_height}")
                    # print(f"Color Image Size: {color_width} x {color_height}")

                    # vis.add_geometry(mesh)
                    vis.add_geometry(pcd_rotated)
                    # pcd_rotated.translate((-20, 10, 0))  # Adjust the translation values as needed

                    # vis.get_view_control().translate(50, 100, 0)

                    # pcd_rotated.material = material  # Apply the custom material


                    # R = mesh.get_rotation_matrix_from_xyz((angle_vector[i],angle_vector[j],angle_vector[k]))
                    # mesh.rotate(R, center=(0, 0, 0))
                    vis.get_view_control().set_zoom(l_zoom)  # Adjust the zoom factor (0.5 zooms out, 2.0 zooms in)

                    vis.poll_events()
                    vis.update_renderer()
                    #vis.reset_view_point()
                    name_ijk = str(i)+'_'+str(j)+'_'+str(k)+'_'+str(l)
                    vis.capture_screen_image(filename = path_save+'img_ '+name_part+'_ '+name_ijk+'.jpg')

                    # o3d.visualization.draw_geometries(draw_geoms_list)
                    view_counter += 1
                    l +=1
                i +=1
            j +=1
        k+=1

    vis.destroy_window()
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/cad-models/
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images2/
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images2/
# Testing IO for meshes ...
# 10_00_0125_0084a_v4a
# TriangleMesh with 444 points and 296 triangles.
# <open3d.cpu.pybind.visualization.Material object at 0x7f9c93624c30>
# Taking image 1 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 2 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 3 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 4 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 5 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 6 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 7 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 8 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 9 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 10 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 11 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 12 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 13 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 14 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 15 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 16 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 17 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 18 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 19 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 20 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 21 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 22 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 23 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 24 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 25 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 26 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 27 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 28 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 29 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 30 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 31 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 32 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 33 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 34 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 35 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 36 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 37 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 38 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 39 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 40 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 41 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 42 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 43 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 44 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 45 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 46 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 47 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 48 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 49 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 50 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 51 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 52 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 53 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 54 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 55 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 56 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 57 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 58 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 59 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 60 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 61 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 62 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 63 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 64 of 216.
# Taking image 65 of 216.
# Taking image 66 of 216.
# Taking image 67 of 216.
# Taking image 68 of 216.
# Taking image 69 of 216.
# Taking image 70 of 216.
# Taking image 71 of 216.
# Taking image 72 of 216.
# Taking image 73 of 216.
# Taking image 74 of 216.
# Taking image 75 of 216.
# Taking image 76 of 216.
# Taking image 77 of 216.
# Taking image 78 of 216.
# Taking image 79 of 216.
# Taking image 80 of 216.
# Taking image 81 of 216.
# Taking image 82 of 216.
# Taking image 83 of 216.
# Taking image 84 of 216.
# Taking image 85 of 216.
# Taking image 86 of 216.
# Taking image 87 of 216.
# Taking image 88 of 216.
# Taking image 89 of 216.
# Taking image 90 of 216.
# Taking image 91 of 216.
# Taking image 92 of 216.
# Taking image 93 of 216.
# Taking image 94 of 216.
# Taking image 95 of 216.
# Taking image 96 of 216.
# Taking image 97 of 216.
# Taking image 98 of 216.
# Taking image 99 of 216.
# Taking image 100 of 216.
# Taking image 101 of 216.
# Taking image 102 of 216.
# Taking image 103 of 216.
# Taking image 104 of 216.
# Taking image 105 of 216.
# Taking image 106 of 216.
# Taking image 107 of 216.
# Taking image 108 of 216.
# Taking image 109 of 216.
# Taking image 110 of 216.
# Taking image 111 of 216.
# Taking image 112 of 216.
# Taking image 113 of 216.
# Taking image 114 of 216.
# Taking image 115 of 216.
# Taking image 116 of 216.
# Taking image 117 of 216.
# Taking image 118 of 216.
# Taking image 119 of 216.
# Taking image 120 of 216.
# Taking image 121 of 216.
# Taking image 122 of 216.
# Taking image 123 of 216.
# Taking image 124 of 216.
# Taking image 125 of 216.
# Taking image 126 of 216.
# Taking image 127 of 216.
# Taking image 128 of 216.
# Taking image 129 of 216.
# Taking image 130 of 216.
# Taking image 131 of 216.
# Taking image 132 of 216.
# Taking image 133 of 216.
# Taking image 134 of 216.
# Taking image 135 of 216.
# Taking image 136 of 216.
# Taking image 137 of 216.
# Taking image 138 of 216.
# Taking image 139 of 216.
# Taking image 140 of 216.
# Taking image 141 of 216.
# Taking image 142 of 216.
# Taking image 143 of 216.
# Taking image 144 of 216.
# Taking image 145 of 216.
# Taking image 146 of 216.
# Taking image 147 of 216.
# Taking image 148 of 216.
# Taking image 149 of 216.
# Taking image 150 of 216.
# Taking image 151 of 216.
# Taking image 152 of 216.
# Taking image 153 of 216.
# Taking image 154 of 216.
# Taking image 155 of 216.
# Taking image 156 of 216.
# Taking image 157 of 216.
# Taking image 158 of 216.
# Taking image 159 of 216.
# Taking image 160 of 216.
# Taking image 161 of 216.
# Taking image 162 of 216.
# Taking image 163 of 216.
# Taking image 164 of 216.
# Taking image 165 of 216.
# Taking image 166 of 216.
# Taking image 167 of 216.
# Taking image 168 of 216.
# Taking image 169 of 216.
# Taking image 170 of 216.
# Taking image 171 of 216.
# Taking image 172 of 216.
# Taking image 173 of 216.
# Taking image 174 of 216.
# Taking image 175 of 216.
# Taking image 176 of 216.
# Taking image 177 of 216.
# Taking image 178 of 216.
# Taking image 179 of 216.
# Taking image 180 of 216.
# Taking image 181 of 216.
# Taking image 182 of 216.
# Taking image 183 of 216.
# Taking image 184 of 216.
# Taking image 185 of 216.
# Taking image 186 of 216.
# Taking image 187 of 216.
# Taking image 188 of 216.
# Taking image 189 of 216.
# Taking image 190 of 216.
# Taking image 191 of 216.
# Taking image 192 of 216.
# Taking image 193 of 216.
# Taking image 194 of 216.
# Taking image 195 of 216.
# Taking image 196 of 216.
# Taking image 197 of 216.
# Taking image 198 of 216.
# Taking image 199 of 216.
# Taking image 200 of 216.
# Taking image 201 of 216.
# Taking image 202 of 216.
# Taking image 203 of 216.
# Taking image 204 of 216.
# Taking image 205 of 216.
# Taking image 206 of 216.
# Taking image 207 of 216.
# Taking image 208 of 216.
# Taking image 209 of 216.
# Taking image 210 of 216.
# Taking image 211 of 216.
# Taking image 212 of 216.
# Taking image 213 of 216.
# Taking image 214 of 216.
# Taking image 215 of 216.
# Taking image 216 of 216.
# Taking image 217 of 216.
# Taking image 218 of 216.
# Taking image 219 of 216.
# Taking image 220 of 216.
# Taking image 221 of 216.
# Taking image 222 of 216.
# Taking image 223 of 216.
# Taking image 224 of 216.
# Taking image 225 of 216.
# Taking image 226 of 216.
# Taking image 227 of 216.
# Taking image 228 of 216.
# Taking image 229 of 216.
# Taking image 230 of 216.
# Taking image 231 of 216.
# Taking image 232 of 216.
# Taking image 233 of 216.
# Taking image 234 of 216.
# Taking image 235 of 216.
# Taking image 236 of 216.
# Taking image 237 of 216.
# Taking image 238 of 216.
# Taking image 239 of 216.
# Taking image 240 of 216.
# Taking image 241 of 216.
# Taking image 242 of 216.
# Taking image 243 of 216.
# Taking image 244 of 216.
# Taking image 245 of 216.
# Taking image 246 of 216.
# Taking image 247 of 216.
# Taking image 248 of 216.
# Taking image 249 of 216.
# Taking image 250 of 216.
# Taking image 251 of 216.
# Taking image 252 of 216.
# Taking image 253 of 216.
# Taking image 254 of 216.
# Taking image 255 of 216.
# Taking image 256 of 216.
# Taking image 257 of 216.
# Taking image 258 of 216.
# Taking image 259 of 216.
# Taking image 260 of 216.
# Taking image 261 of 216.
# Taking image 262 of 216.
# Taking image 263 of 216.
# Taking image 264 of 216.
# Taking image 265 of 216.
# Taking image 266 of 216.
# Taking image 267 of 216.
# Taking image 268 of 216.
# Taking image 269 of 216.
# Taking image 270 of 216.
# Taking image 271 of 216.
# Taking image 272 of 216.
# Taking image 273 of 216.
# Taking image 274 of 216.
# Taking image 275 of 216.
# Taking image 276 of 216.
# Taking image 277 of 216.
# Taking image 278 of 216.
# Taking image 279 of 216.
# Taking image 280 of 216.
# Taking image 281 of 216.
# Taking image 282 of 216.
# Taking image 283 of 216.
# Taking image 284 of 216.
# Taking image 285 of 216.
# Taking image 286 of 216.
# Taking image 287 of 216.
# Taking image 288 of 216.
# Taking image 289 of 216.
# Taking image 290 of 216.
# Taking image 291 of 216.
# Taking image 292 of 216.
# Taking image 293 of 216.
# Taking image 294 of 216.
# Taking image 295 of 216.
# Taking image 296 of 216.
# Taking image 297 of 216.
# Taking image 298 of 216.
# Taking image 299 of 216.
# Taking image 300 of 216.
# Taking image 301 of 216.
# Taking image 302 of 216.
# Taking image 303 of 216.
# Taking image 304 of 216.
# Taking image 305 of 216.
# Taking image 306 of 216.
# Taking image 307 of 216.
# Taking image 308 of 216.
# Taking image 309 of 216.
# Taking image 310 of 216.
# Taking image 311 of 216.
# Taking image 312 of 216.
# Taking image 313 of 216.
# Taking image 314 of 216.
# Taking image 315 of 216.
# Taking image 316 of 216.
# Taking image 317 of 216.
# Taking image 318 of 216.
# Taking image 319 of 216.
# Taking image 320 of 216.
# Taking image 321 of 216.
# Taking image 322 of 216.
# Taking image 323 of 216.
# Taking image 324 of 216.
# Taking image 325 of 216.
# Taking image 326 of 216.
# Taking image 327 of 216.
# Taking image 328 of 216.
# Taking image 329 of 216.
# Taking image 330 of 216.
# Taking image 331 of 216.
# Taking image 332 of 216.
# Taking image 333 of 216.
# Taking image 334 of 216.
# Taking image 335 of 216.
# Taking image 336 of 216.
# Taking image 337 of 216.
# Taking image 338 of 216.
# Taking image 339 of 216.
# Taking image 340 of 216.
# Taking image 341 of 216.
# Taking image 342 of 216.
# Taking image 343 of 216.
# Taking image 344 of 216.
# Taking image 345 of 216.
# Taking image 346 of 216.
# Taking image 347 of 216.
# Taking image 348 of 216.
# Taking image 349 of 216.
# Taking image 350 of 216.
# Taking image 351 of 216.
# Taking image 352 of 216.
# Taking image 353 of 216.
# Taking image 354 of 216.
# Taking image 355 of 216.
# Taking image 356 of 216.
# Taking image 357 of 216.
# Taking image 358 of 216.
# Taking image 359 of 216.
# Taking image 360 of 216.
# Taking image 361 of 216.
# Taking image 362 of 216.
# Taking image 363 of 216.
# Taking image 364 of 216.
# Taking image 365 of 216.
# Taking image 366 of 216.
# Taking image 367 of 216.
# Taking image 368 of 216.
# Taking image 369 of 216.
# Taking image 370 of 216.
# Taking image 371 of 216.
# Taking image 372 of 216.
# Taking image 373 of 216.
# Taking image 374 of 216.
# Taking image 375 of 216.
# Taking image 376 of 216.
# Taking image 377 of 216.
# Taking image 378 of 216.
# Taking image 379 of 216.
# Taking image 380 of 216.
# Taking image 381 of 216.
# Taking image 382 of 216.
# Taking image 383 of 216.
# Taking image 384 of 216.
# Taking image 385 of 216.
# Taking image 386 of 216.
# Taking image 387 of 216.
# Taking image 388 of 216.
# Taking image 389 of 216.
# Taking image 390 of 216.
# Taking image 391 of 216.
# Taking image 392 of 216.
# Taking image 393 of 216.
# Taking image 394 of 216.
# Taking image 395 of 216.
# Taking image 396 of 216.
# Taking image 397 of 216.
# Taking image 398 of 216.
# Taking image 399 of 216.
# Taking image 400 of 216.
# Taking image 401 of 216.
# Taking image 402 of 216.
# Taking image 403 of 216.
# Taking image 404 of 216.
# Taking image 405 of 216.
# Taking image 406 of 216.
# Taking image 407 of 216.
# Taking image 408 of 216.
# Taking image 409 of 216.
# Taking image 410 of 216.
# Taking image 411 of 216.
# Taking image 412 of 216.
# Taking image 413 of 216.
# Taking image 414 of 216.
# Taking image 415 of 216.
# Taking image 416 of 216.
# Taking image 417 of 216.
# Taking image 418 of 216.
# Taking image 419 of 216.
# Taking image 420 of 216.
# Taking image 421 of 216.
# Taking image 422 of 216.
# Taking image 423 of 216.
# Taking image 424 of 216.
# Taking image 425 of 216.
# Taking image 426 of 216.
# Taking image 427 of 216.
# Taking image 428 of 216.
# Taking image 429 of 216.
# Taking image 430 of 216.
# Taking image 431 of 216.
# Taking image 432 of 216.
# Taking image 433 of 216.
# Taking image 434 of 216.
# Taking image 435 of 216.
# Taking image 436 of 216.
# Taking image 437 of 216.
# Taking image 438 of 216.
# Taking image 439 of 216.
# Taking image 440 of 216.
# Taking image 441 of 216.
# Taking image 442 of 216.
# Taking image 443 of 216.
# Taking image 444 of 216.
# Taking image 445 of 216.
# Taking image 446 of 216.
# Taking image 447 of 216.
# Taking image 448 of 216.
# Taking image 449 of 216.
# Taking image 450 of 216.
# Taking image 451 of 216.
# Taking image 452 of 216.
# Taking image 453 of 216.
# Taking image 454 of 216.
# Taking image 455 of 216.
# Taking image 456 of 216.
# Taking image 457 of 216.
# Taking image 458 of 216.
# Taking image 459 of 216.
# Taking image 460 of 216.
# Taking image 461 of 216.
# Taking image 462 of 216.
# Taking image 463 of 216.
# Taking image 464 of 216.
# Taking image 465 of 216.
# Taking image 466 of 216.
# Taking image 467 of 216.
# Taking image 468 of 216.
# Taking image 469 of 216.
# Taking image 470 of 216.
# Taking image 471 of 216.
# Taking image 472 of 216.
# Taking image 473 of 216.
# Taking image 474 of 216.
# Taking image 475 of 216.
# Taking image 476 of 216.
# Taking image 477 of 216.
# Taking image 478 of 216.
# Taking image 479 of 216.
# Taking image 480 of 216.
# Taking image 481 of 216.
# Taking image 482 of 216.
# Taking image 483 of 216.
# Taking image 484 of 216.
# Taking image 485 of 216.
# Taking image 486 of 216.
# Taking image 487 of 216.
# Taking image 488 of 216.
# Taking image 489 of 216.
# Taking image 490 of 216.
# Taking image 491 of 216.
# Taking image 492 of 216.
# Taking image 493 of 216.
# Taking image 494 of 216.
# Taking image 495 of 216.
# Taking image 496 of 216.
# Taking image 497 of 216.
# Taking image 498 of 216.
# Taking image 499 of 216.
# Taking image 500 of 216.
# Taking image 501 of 216.
# Taking image 502 of 216.
# Taking image 503 of 216.
# Taking image 504 of 216.
# Taking image 505 of 216.
# Taking image 506 of 216.
# Taking image 507 of 216.
# Taking image 508 of 216.
# Taking image 509 of 216.
# Taking image 510 of 216.
# Taking image 511 of 216.
# Taking image 512 of 216.
# Taking image 513 of 216.
# Taking image 514 of 216.
# Taking image 515 of 216.
# Taking image 516 of 216.
# Taking image 517 of 216.
# Taking image 518 of 216.
# Taking image 519 of 216.
# Taking image 520 of 216.
# Taking image 521 of 216.
# Taking image 522 of 216.
# Taking image 523 of 216.
# Taking image 524 of 216.
# Taking image 525 of 216.
# Taking image 526 of 216.
# Taking image 527 of 216.
# Taking image 528 of 216.
# Taking image 529 of 216.
# Taking image 530 of 216.
# Taking image 531 of 216.
# Taking image 532 of 216.
# Taking image 533 of 216.
# Taking image 534 of 216.
# Taking image 535 of 216.
# Taking image 536 of 216.
# Taking image 537 of 216.
# Taking image 538 of 216.
# Taking image 539 of 216.
# Taking image 540 of 216.
# Taking image 541 of 216.
# Taking image 542 of 216.
# Taking image 543 of 216.
# Taking image 544 of 216.
# Taking image 545 of 216.
# Taking image 546 of 216.
# Taking image 547 of 216.
# Taking image 548 of 216.
# Taking image 549 of 216.
# Taking image 550 of 216.
# Taking image 551 of 216.
# Taking image 552 of 216.
# Taking image 553 of 216.
# Taking image 554 of 216.
# Taking image 555 of 216.
# Taking image 556 of 216.
# Taking image 557 of 216.
# Taking image 558 of 216.
# Taking image 559 of 216.
# Taking image 560 of 216.
# Taking image 561 of 216.
# Taking image 562 of 216.
# Taking image 563 of 216.
# Taking image 564 of 216.
# Taking image 565 of 216.
# Taking image 566 of 216.
# Taking image 567 of 216.
# Taking image 568 of 216.
# Taking image 569 of 216.
# Taking image 570 of 216.
# Taking image 571 of 216.
# Taking image 572 of 216.
# Taking image 573 of 216.
# Taking image 574 of 216.
# Taking image 575 of 216.
# Taking image 576 of 216.
# Taking image 577 of 216.
# Taking image 578 of 216.
# Taking image 579 of 216.
# Taking image 580 of 216.
# Taking image 581 of 216.
# Taking image 582 of 216.
# Taking image 583 of 216.
# Taking image 584 of 216.
# Taking image 585 of 216.
# Taking image 586 of 216.
# Taking image 587 of 216.
# Taking image 588 of 216.
# Taking image 589 of 216.
# Taking image 590 of 216.
# Taking image 591 of 216.
# Taking image 592 of 216.
# Taking image 593 of 216.
# Taking image 594 of 216.
# Taking image 595 of 216.
# Taking image 596 of 216.
# Taking image 597 of 216.
# Taking image 598 of 216.
# Taking image 599 of 216.
# Taking image 600 of 216.
# Taking image 601 of 216.
# Taking image 602 of 216.
# Taking image 603 of 216.
# Taking image 604 of 216.
# Taking image 605 of 216.
# Taking image 606 of 216.
# Taking image 607 of 216.
# Taking image 608 of 216.
# Taking image 609 of 216.
# Taking image 610 of 216.
# Taking image 611 of 216.
# Taking image 612 of 216.
# Taking image 613 of 216.
# Taking image 614 of 216.
# Taking image 615 of 216.
# Taking image 616 of 216.
# Taking image 617 of 216.
# Taking image 618 of 216.
# Taking image 619 of 216.
# Taking image 620 of 216.
# Taking image 621 of 216.
# Taking image 622 of 216.
# Taking image 623 of 216.
# Taking image 624 of 216.
# Taking image 625 of 216.
# Taking image 626 of 216.
# Taking image 627 of 216.
# Taking image 628 of 216.
# Taking image 629 of 216.
# Taking image 630 of 216.
# Taking image 631 of 216.
# Taking image 632 of 216.
# Taking image 633 of 216.
# Taking image 634 of 216.
# Taking image 635 of 216.
# Taking image 636 of 216.
# Taking image 637 of 216.
# Taking image 638 of 216.
# Taking image 639 of 216.
# Taking image 640 of 216.
# Taking image 641 of 216.
# Taking image 642 of 216.
# Taking image 643 of 216.
# Taking image 644 of 216.
# Taking image 645 of 216.
# Taking image 646 of 216.
# Taking image 647 of 216.
# Taking image 648 of 216.
# Taking image 649 of 216.
# Taking image 650 of 216.
# Taking image 651 of 216.
# Taking image 652 of 216.
# Taking image 653 of 216.
# Taking image 654 of 216.
# Taking image 655 of 216.
# Taking image 656 of 216.
# Taking image 657 of 216.
# Taking image 658 of 216.
# Taking image 659 of 216.
# Taking image 660 of 216.
# Taking image 661 of 216.
# Taking image 662 of 216.
# Taking image 663 of 216.
# Taking image 664 of 216.
# Taking image 665 of 216.
# Taking image 666 of 216.
# Taking image 667 of 216.
# Taking image 668 of 216.
# Taking image 669 of 216.
# Taking image 670 of 216.
# Taking image 671 of 216.
# Taking image 672 of 216.
# Taking image 673 of 216.
# Taking image 674 of 216.
# Taking image 675 of 216.
# Taking image 676 of 216.
# Taking image 677 of 216.
# Taking image 678 of 216.
# Taking image 679 of 216.
# Taking image 680 of 216.
# Taking image 681 of 216.
# Taking image 682 of 216.
# Taking image 683 of 216.
# Taking image 684 of 216.
# Taking image 685 of 216.
# Taking image 686 of 216.
# Taking image 687 of 216.
# Taking image 688 of 216.
# Taking image 689 of 216.
# Taking image 690 of 216.
# Taking image 691 of 216.
# Taking image 692 of 216.
# Taking image 693 of 216.
# Taking image 694 of 216.
# Taking image 695 of 216.
# Taking image 696 of 216.
# Taking image 697 of 216.
# Taking image 698 of 216.
# Taking image 699 of 216.
# Taking image 700 of 216.
# Taking image 701 of 216.
# Taking image 702 of 216.
# Taking image 703 of 216.
# Taking image 704 of 216.
# Taking image 705 of 216.
# Taking image 706 of 216.
# Taking image 707 of 216.
# Taking image 708 of 216.
# Taking image 709 of 216.
# Taking image 710 of 216.
# Taking image 711 of 216.
# Taking image 712 of 216.
# Taking image 713 of 216.
# Taking image 714 of 216.
# Taking image 715 of 216.
# Taking image 716 of 216.
# Taking image 717 of 216.
# Taking image 718 of 216.
# Taking image 719 of 216.
# Taking image 720 of 216.
# Taking image 721 of 216.
# Taking image 722 of 216.
# Taking image 723 of 216.
# Taking image 724 of 216.
# Taking image 725 of 216.
# Taking image 726 of 216.
# Taking image 727 of 216.
# Taking image 728 of 216.
# Taking image 729 of 216.
# Taking image 730 of 216.
# Taking image 731 of 216.
# Taking image 732 of 216.
# Taking image 733 of 216.
# Taking image 734 of 216.
# Taking image 735 of 216.
# Taking image 736 of 216.
# Taking image 737 of 216.
# Taking image 738 of 216.
# Taking image 739 of 216.
# Taking image 740 of 216.
# Taking image 741 of 216.
# Taking image 742 of 216.
# Taking image 743 of 216.
# Taking image 744 of 216.
# Taking image 745 of 216.
# Taking image 746 of 216.
# Taking image 747 of 216.
# Taking image 748 of 216.
# Taking image 749 of 216.
# Taking image 750 of 216.
# Taking image 751 of 216.
# Taking image 752 of 216.
# Taking image 753 of 216.
# Taking image 754 of 216.
# Taking image 755 of 216.
# Taking image 756 of 216.
# Taking image 757 of 216.
# Taking image 758 of 216.
# Taking image 759 of 216.
# Taking image 760 of 216.
# Taking image 761 of 216.
# Taking image 762 of 216.
# Taking image 763 of 216.
# Taking image 764 of 216.
# Taking image 765 of 216.
# Taking image 766 of 216.
# Taking image 767 of 216.
# Taking image 768 of 216.
# Taking image 769 of 216.
# Taking image 770 of 216.
# Taking image 771 of 216.
# Taking image 772 of 216.
# Taking image 773 of 216.
# Taking image 774 of 216.
# Taking image 775 of 216.
# Taking image 776 of 216.
# Taking image 777 of 216.
# Taking image 778 of 216.
# Taking image 779 of 216.
# Taking image 780 of 216.
# Taking image 781 of 216.
# Taking image 782 of 216.
# Taking image 783 of 216.
# Taking image 784 of 216.
# Taking image 785 of 216.
# Taking image 786 of 216.
# Taking image 787 of 216.
# Taking image 788 of 216.
# Taking image 789 of 216.
# Taking image 790 of 216.
# Taking image 791 of 216.
# Taking image 792 of 216.
# Taking image 793 of 216.
# Taking image 794 of 216.
# Taking image 795 of 216.
# Taking image 796 of 216.
# Taking image 797 of 216.
# Taking image 798 of 216.
# Taking image 799 of 216.
# Taking image 800 of 216.
# Taking image 801 of 216.
# Taking image 802 of 216.
# Taking image 803 of 216.
# Taking image 804 of 216.
# Taking image 805 of 216.
# Taking image 806 of 216.
# Taking image 807 of 216.
# Taking image 808 of 216.
# Taking image 809 of 216.
# Taking image 810 of 216.
# Taking image 811 of 216.
# Taking image 812 of 216.
# Taking image 813 of 216.
# Taking image 814 of 216.
# Taking image 815 of 216.
# Taking image 816 of 216.
# Taking image 817 of 216.
# Taking image 818 of 216.
# Taking image 819 of 216.
# Taking image 820 of 216.
# Taking image 821 of 216.
# Taking image 822 of 216.
# Taking image 823 of 216.
# Taking image 824 of 216.
# Taking image 825 of 216.
# Taking image 826 of 216.
# Taking image 827 of 216.
# Taking image 828 of 216.
# Taking image 829 of 216.
# Taking image 830 of 216.
# Taking image 831 of 216.
# Taking image 832 of 216.
# Taking image 833 of 216.
# Taking image 834 of 216.
# Taking image 835 of 216.
# Taking image 836 of 216.
# Taking image 837 of 216.
# Taking image 838 of 216.
# Taking image 839 of 216.
# Taking image 840 of 216.
# Taking image 841 of 216.
# Taking image 842 of 216.
# Taking image 843 of 216.
# Taking image 844 of 216.
# Taking image 845 of 216.
# Taking image 846 of 216.
# Taking image 847 of 216.
# Taking image 848 of 216.
# Taking image 849 of 216.
# Taking image 850 of 216.
# Taking image 851 of 216.
# Taking image 852 of 216.
# Taking image 853 of 216.
# Taking image 854 of 216.
# Taking image 855 of 216.
# Taking image 856 of 216.
# Taking image 857 of 216.
# Taking image 858 of 216.
# Taking image 859 of 216.
# Taking image 860 of 216.
# Taking image 861 of 216.
# Taking image 862 of 216.
# Taking image 863 of 216.
# Taking image 864 of 216.
# Testing IO for meshes ...
# dst4
# TriangleMesh with 1016 points and 472 triangles.
# <open3d.cpu.pybind.visualization.Material object at 0x7f9cb13008b0>
# Taking image 1 of 216.
# Taking image 2 of 216.
# Taking image 3 of 216.
# Taking image 4 of 216.
# Taking image 5 of 216.
# Taking image 6 of 216.
# Taking image 7 of 216.
# Taking image 8 of 216.
# Taking image 9 of 216.
# Taking image 10 of 216.
# Taking image 11 of 216.
# Taking image 12 of 216.
# Taking image 13 of 216.
# Taking image 14 of 216.
# Taking image 15 of 216.
# Taking image 16 of 216.
# Taking image 17 of 216.
# Taking image 18 of 216.
# Taking image 19 of 216.
# Taking image 20 of 216.
# Taking image 21 of 216.
# Taking image 22 of 216.
# Taking image 23 of 216.
# Taking image 24 of 216.
# Taking image 25 of 216.
# Taking image 26 of 216.
# Taking image 27 of 216.
# Taking image 28 of 216.
# Taking image 29 of 216.
# Taking image 30 of 216.
# Taking image 31 of 216.
# Taking image 32 of 216.
# Taking image 33 of 216.
# Taking image 34 of 216.
# Taking image 35 of 216.
# Taking image 36 of 216.
# Taking image 37 of 216.
# Taking image 38 of 216.
# Taking image 39 of 216.
# Taking image 40 of 216.
# Taking image 41 of 216.
# Taking image 42 of 216.
# Taking image 43 of 216.
# Taking image 44 of 216.
# Taking image 45 of 216.
# Taking image 46 of 216.
# Taking image 47 of 216.
# Taking image 48 of 216.
# Taking image 49 of 216.
# Taking image 50 of 216.
# Taking image 51 of 216.
# Taking image 52 of 216.
# Taking image 53 of 216.
# Taking image 54 of 216.
# Taking image 55 of 216.
# Taking image 56 of 216.
# Taking image 57 of 216.
# Taking image 58 of 216.
# Taking image 59 of 216.
# Taking image 60 of 216.
# Taking image 61 of 216.
# Taking image 62 of 216.
# Taking image 63 of 216.
# Taking image 64 of 216.
# Taking image 65 of 216.
# Taking image 66 of 216.
# Taking image 67 of 216.
# Taking image 68 of 216.
# Taking image 69 of 216.
# Taking image 70 of 216.
# Taking image 71 of 216.
# Taking image 72 of 216.
# Taking image 73 of 216.
# Taking image 74 of 216.
# Taking image 75 of 216.
# Taking image 76 of 216.
# Taking image 77 of 216.
# Taking image 78 of 216.
# Taking image 79 of 216.
# Taking image 80 of 216.
# Taking image 81 of 216.
# Taking image 82 of 216.
# Taking image 83 of 216.
# Taking image 84 of 216.
# Taking image 85 of 216.
# Taking image 86 of 216.
# Taking image 87 of 216.
# Taking image 88 of 216.
# Taking image 89 of 216.
# Taking image 90 of 216.
# Taking image 91 of 216.
# Taking image 92 of 216.
# Taking image 93 of 216.
# Taking image 94 of 216.
# Taking image 95 of 216.
# Taking image 96 of 216.
# Taking image 97 of 216.
# Taking image 98 of 216.
# Taking image 99 of 216.
# Taking image 100 of 216.
# Taking image 101 of 216.
# Taking image 102 of 216.
# Taking image 103 of 216.
# Taking image 104 of 216.
# Taking image 105 of 216.
# Taking image 106 of 216.
# Taking image 107 of 216.
# Taking image 108 of 216.
# Taking image 109 of 216.
# Taking image 110 of 216.
# Taking image 111 of 216.
# Taking image 112 of 216.
# Taking image 113 of 216.
# Taking image 114 of 216.
# Taking image 115 of 216.
# Taking image 116 of 216.
# Taking image 117 of 216.
# Taking image 118 of 216.
# Taking image 119 of 216.
# Taking image 120 of 216.
# Taking image 121 of 216.
# Taking image 122 of 216.
# Taking image 123 of 216.
# Taking image 124 of 216.
# Taking image 125 of 216.
# Taking image 126 of 216.
# Taking image 127 of 216.
# Taking image 128 of 216.
# Taking image 129 of 216.
# Taking image 130 of 216.
# Taking image 131 of 216.
# Taking image 132 of 216.
# Taking image 133 of 216.
# Taking image 134 of 216.
# Taking image 135 of 216.
# Taking image 136 of 216.
# Taking image 137 of 216.
# Taking image 138 of 216.
# Taking image 139 of 216.
# Taking image 140 of 216.
# Taking image 141 of 216.
# Taking image 142 of 216.
# Taking image 143 of 216.
# Taking image 144 of 216.
# Taking image 145 of 216.
# Taking image 146 of 216.
# Taking image 147 of 216.
# Taking image 148 of 216.
# Taking image 149 of 216.
# Taking image 150 of 216.
# Taking image 151 of 216.
# Taking image 152 of 216.
# Taking image 153 of 216.
# Taking image 154 of 216.
# Taking image 155 of 216.
# Taking image 156 of 216.
# Taking image 157 of 216.
# Taking image 158 of 216.
# Taking image 159 of 216.
# Taking image 160 of 216.
# Taking image 161 of 216.
# Taking image 162 of 216.
# Taking image 163 of 216.
# Taking image 164 of 216.
# Taking image 165 of 216.
# Taking image 166 of 216.
# Taking image 167 of 216.
# Taking image 168 of 216.
# Taking image 169 of 216.
# Taking image 170 of 216.
# Taking image 171 of 216.
# Taking image 172 of 216.
# Taking image 173 of 216.
# Taking image 174 of 216.
# Taking image 175 of 216.
# Taking image 176 of 216.
# Taking image 177 of 216.
# Taking image 178 of 216.
# Taking image 179 of 216.
# Taking image 180 of 216.
# Taking image 181 of 216.
# Taking image 182 of 216.
# Taking image 183 of 216.
# Taking image 184 of 216.
# Taking image 185 of 216.
# Taking image 186 of 216.
# Taking image 187 of 216.
# Taking image 188 of 216.
# Taking image 189 of 216.
# Taking image 190 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 191 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 192 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 193 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 194 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 195 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 196 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 197 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 198 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 199 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 200 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 201 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 202 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 203 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 204 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 205 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 206 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 207 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 208 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 209 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 210 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 211 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 212 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 213 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 214 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 215 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 216 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 217 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 218 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 219 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 220 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 221 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 222 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 223 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 224 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 225 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 226 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 227 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 228 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 229 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 230 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 231 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 232 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 233 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 234 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 235 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 236 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 237 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 238 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 239 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 240 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 241 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 242 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 243 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 244 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 245 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 246 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 247 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 248 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 249 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 250 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 251 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 252 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 253 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 254 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 255 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 256 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 257 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 258 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 259 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 260 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 261 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 262 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 263 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 264 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 265 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 266 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 267 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 268 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 269 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 270 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 271 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 272 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 273 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 274 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 275 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 276 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 277 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 278 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 279 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 280 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 281 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 282 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 283 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 284 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 285 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 286 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 287 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 288 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 289 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 290 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 291 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 292 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 293 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 294 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 295 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 296 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 297 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 298 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 299 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 300 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 301 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 302 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 303 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 304 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 305 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 306 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 307 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 308 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 309 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 310 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 311 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 312 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 313 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 314 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 315 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 316 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 317 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 318 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 319 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 320 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 321 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 322 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 323 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 324 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 325 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 326 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 327 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 328 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 329 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 330 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 331 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 332 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 333 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 334 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 335 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 336 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 337 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 338 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 339 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 340 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 341 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 342 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 343 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 344 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 345 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 346 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 347 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 348 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 349 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 350 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 351 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 352 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 353 of 216.
# ...
# Taking image 707 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 708 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 709 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 710 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 711 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 712 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 713 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 714 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 715 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 716 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 717 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 718 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 719 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 720 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 721 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 722 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 723 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 724 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 725 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 726 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 727 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 728 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 729 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 730 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 731 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 732 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 733 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 734 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 735 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 736 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 737 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 738 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 739 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 740 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 741 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 742 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 743 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 744 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 745 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 746 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 747 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 748 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 749 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 750 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 751 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 752 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 753 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 754 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 755 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 756 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 757 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 758 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 759 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 760 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 761 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 762 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 763 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 764 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 765 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 766 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 767 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 768 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 769 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 770 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 771 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 772 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 773 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 774 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 775 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 776 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 777 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 778 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 779 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 780 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 781 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 782 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 783 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 784 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 785 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 786 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 787 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 788 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 789 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 790 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 791 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 792 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 793 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 794 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 795 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 796 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 797 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 798 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 799 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 800 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 801 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 802 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 803 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 804 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 805 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 806 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 807 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 808 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 809 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 810 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 811 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 812 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 813 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 814 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 815 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 816 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 817 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 818 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 819 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 820 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 821 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 822 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 823 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 824 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 825 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 826 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 827 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 828 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 829 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 830 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 831 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 832 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 833 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 834 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 835 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 836 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 837 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 838 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 839 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 840 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 841 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 842 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 843 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 844 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 845 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 846 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 847 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 848 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 849 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 850 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 851 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 852 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 853 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 854 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 855 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 856 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 857 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 858 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 859 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 860 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 861 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 862 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 863 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 864 of 216.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
data_path = parent_dir+'/data/'
cad_path = data_path + 'cad-models/'
print(cad_path)
file_extension = '.stl'
path_save = data_path+'train/images2/'
labels_save = data_path+'train/labels2/'
print(path_save)
files = get_files_in_subdirectories(cad_path,file_extension)
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/cad-models/
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train/images2/

# %%
import cv2
images_move = get_files_in_subdirectories(path_save,'.jpg')

unique_classes = []

for jpg in images_move:
    # Load the image
    image = cv2.imread(jpg)

    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Perform edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours in the edge-detected image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Find the convex hull of the contours
    convex_hull = cv2.convexHull(np.vstack(contours))

    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Calculate the bounding box of the convex hull
    x, y, w, h = cv2.boundingRect(convex_hull)

    x1 = x
    y1 = y
    x2 = x + w
    y2 = y + h

    # Calculate the maximum x and y coordinates for the new location
    max_x = image.shape[1] - w
    max_y = image.shape[0] - h

    # Generate random x and y coordinates for the new location
    new_x = np.random.randint(0, max_x + 1)
    new_y = np.random.randint(0, max_y + 1)

    # Extract the object
    object_region = image[y1:y2, x1:x2].copy()

    # Paste the object into the new random location
    image[y1:y2, x1:x2] = [255, 255, 255]
    image[new_y:new_y+h, new_x:new_x+w] = object_region

    # Save the edited image
    cv2.imwrite(jpg, image)
    
    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Draw the bounding box on the result image
    cv2.rectangle(result_image, (new_x, new_y), (new_x + w, new_y + h), (0, 255, 0), 2)
    bounding_box_saving_path = jpg.replace("images2", "images2_wbb")
    cv2.imwrite(bounding_box_saving_path, result_image)

    center_x = new_x + (w) / 2
    center_y = new_y + (h) / 2
    relative_width = (w) / image.shape[1]
    #print(relative_width)
    relative_height = (h) / image.shape[0]
    #print(relative_height)
    relative_center_x= center_x / image.shape[1]
    relative_center_y= center_y / image.shape[0]

    # Open a file for writing the results
    filename = jpg.split('/')[-1].split('.')[0]
    classname = filename.split('_ ')[1]
    if classname not in unique_classes:
        unique_classes.append(classname)
    encoded_class = unique_classes.index(classname)
    with open(labels_save + filename + '.txt', 'w') as file:
        file.write(f"{encoded_class} {relative_center_x:.5f} {relative_center_y:.5f} {relative_width:.5f} {relative_height:.5f}")
