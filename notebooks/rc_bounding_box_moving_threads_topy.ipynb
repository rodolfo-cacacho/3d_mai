# %%
import numpy as np
import copy
import os
import re
import random
from PIL import Image
import cv2
import yaml
from matplotlib import pyplot as plt

# %%
def get_files_by_extension(folder_path, extension):
    files = [file for file in os.listdir(folder_path) if file.endswith(f".{extension}")]
    return files

def get_subdirectories(folder_path):
    subdirectories = []
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            subdirectories.append(item)
    return subdirectories

def get_files_in_subdirectories(folder_path, file_extension='', file_contains=''):
    files = []
    for root, directories, filenames in os.walk(folder_path):
        for filename in filenames:
            if file_extension == '' and file_contains == '':
                files.append(os.path.join(root, filename))
            elif file_extension != '' and file_contains == '':
                if filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
            elif file_extension == '' and file_contains != '':
                if file_contains in filename:
                    files.append(os.path.join(root, filename))
            else:
                if file_contains in filename and filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
    return files


def extract_string(filename,format = 'stl'):
    pattern = r'\/([^/]+)\.'+format+'$'
    match = re.search(pattern, filename)
    if match:
        return match.group(1)
    else:
        return None
    
# Defining a function to convert degrees to radians.
def deg2rad(deg):
    return deg * np.pi/180

def get_rotated_pcd(pcd, x_theta, y_theta, z_theta):
    pcd_rotated = copy.deepcopy(pcd)
    R = pcd_rotated.get_rotation_matrix_from_axis_angle([x_theta, y_theta, z_theta])
    pcd_rotated.rotate(R, center=(0, 0, 0))
    return pcd_rotated

def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
        return False
    else:
        print(f"Folder already exists: {folder_path}")
        return True

def delete_file(file_path):
    try:
        os.remove(file_path)
        # print(f"File '{file_path}' deleted successfully.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
    except PermissionError:
        print(f"Permission denied: unable to delete file '{file_path}'.")
    except Exception as e:
        print(f"An error occurred while deleting the file: {e}")

def create_binary_list(n, percentage_of_ones):
    if percentage_of_ones < 0 or percentage_of_ones > 100:
        raise ValueError("Percentage_of_ones must be between 0 and 100")

    num_ones = int(n * (percentage_of_ones / 100))
    num_zeros = n - num_ones

    binary_list = [1] * num_ones + [0] * num_zeros
    random.shuffle(binary_list)

    return binary_list

def percentages_to_coordinates(bbox_percentages, image_width, image_height):
    rx, ry, rwo, rho = bbox_percentages

    ho = rho*image_height
    wo = rwo*image_width
    # print(f'height o {ho} width {wo}')
    # print(f'height i {image_height} width {image_width}')

    x_1 = int((rx*image_width-wo/2.0))
    y_1 = int((ry*image_height-ho/2.0))
    x_2 = int((x_1 + wo))
    y_2 = int((y_1 + ho))

    return x_1, y_1, x_2, y_2

def coordinates_to_percentage(bbox_coordinates, image_width, image_height):
    x1,y1,x2,y2 = bbox_coordinates

    wo = x2-x1
    ho = y2-y1

    rxo = round((x1 + wo/2.0)/image_width,4)
    ryo = round((y1 + ho/2.0)/image_height,4)
    rwo = round(wo/image_width,4)
    rho = round(ho/image_height,4)

    return rxo,ryo,rwo,rho

# %%
cwd = os.getcwd()
print(f'a {cwd}')

## App path
parent_dir = '/Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/'
os.chdir(parent_dir)
cwd = os.getcwd()
print(f'b {cwd}')

parent_dir = cwd
# data_path = parent_dir+'/data/'
cad_path = parent_dir + '/cad-files/'
cad_path_sp = cad_path + 'single-parts/'
cad_path_ass = cad_path + 'assemblies/'
print(cad_path)
file_extension = '.stl'
# path_save = data_path+'train_threads/imagesO/'
# print(path_save)
files_ass = get_files_in_subdirectories(cad_path_ass,file_extension)
files_sp = get_files_in_subdirectories(cad_path_sp,file_extension)
# Out:
# a /Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application
# b /Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/cad-files/

# %%
files_sp
# Out:
# ['/Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/cad-files/single-parts/dst4.stl',
#  '/Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/cad-files/single-parts/m4_10mm.stl',
#  '/Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/cad-files/single-parts/m4_20mm.stl',
#  '/Users/rodolfocacacho/Documents/Documents/MAI/Project module/test_application/cad-files/single-parts/din125_m4.stl']

# %%
cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
data_path = parent_dir+'/data/'
cad_path = data_path + 'cad-models-threads/'
print(cad_path)
file_extension = '.stl'
path_imgs = data_path+'train_threads_b/imagesO/'
path_save = path_imgs.replace('imagesO','images')
path_val_save = path_save.replace('train','val')
labels_save = data_path+'train_threads_b/labels/'
labels_val_save = data_path+'val_threads_b/labels/'
path_save_bb = data_path+'train_threads_b/images_wbb/'
print(path_save)
files = get_files_in_subdirectories(cad_path,file_extension)
val_save = ''

exists_save = create_folder_if_not_exists(path_save)
if exists_save:
    images_del = get_files_in_subdirectories(path_save,'png')
    for imdel in images_del:
        delete_file(imdel)
exists_lb = create_folder_if_not_exists(labels_save)
if exists_lb:
    images_del = get_files_in_subdirectories(labels_save,'txt')
    for imdel in images_del:
        delete_file(imdel)
exists_wbb = create_folder_if_not_exists(path_save_bb)
if exists_wbb:
    images_del = get_files_in_subdirectories(path_save_bb,'png')
    for imdel in images_del:
        delete_file(imdel)
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/cad-models-threads/
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/images/
# Created folder: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/images/
# Created folder: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/labels/
# Created folder: /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/images_wbb/

# %%
def get_class_yolo_ass_sp(file_path_assemblies,file_path_single_parts):
    
    return class_list

def get_class_obj(file_name):
    filename = file_name.split('/')[-1].split('.')[0]
    classname = filename.split('_x')[0]

    return classname

def extract_obj(image_path,image_class,is_assembly):
    image = cv2.imread(image_path)
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    # Perform edge detection
    edges = cv2.Canny(blurred, 50, 150)
    # Find contours in the edge-detected image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # Find the convex hull of the contours
    convex_hull = cv2.convexHull(np.vstack(contours))
    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()
    # Calculate the bounding box of the convex hull
    x, y, w, h = cv2.boundingRect(convex_hull)
    image_width = image.shape[1]
    image_height = image.shape[0] 
    aratio = w/h
    if aratio >= 1:
        px = 1
        py = int(1*aratio)
    else:
        px = int(1.0/aratio)
        py = 1
    x1 = x-px
    y1 = y-py
    x2 = x + w + px
    y2 = y + h + py
    wn = x2-x1
    hn = y2-y1
    w_reduce = 960
    h_reduce = 500
    # Calculate the maximum x and y coordinates for the new location
    max_x = image_width - w - int(w_reduce/2)
    max_y = image_height - h - int(h_reduce/2)

    # Generate random x and y coordinates for the new location
    new_x = np.random.randint(int(w_reduce/2), max_x + 1)
    new_y = np.random.randint(int(h_reduce/2), max_y + 1)
    if is_assembly:
        new_x = x1
        new_y = y1
    # Extract the object
    object_region = image[y1:y2, x1:x2].copy()

    # Paste the object into the new random location
    image[y1:y2, x1:x2] = [255, 255, 255]
    image[new_y:new_y+hn, new_x:new_x+wn] = object_region

    jpg_saving_path = jpg.replace("imagesO", "images")
    cv2.imwrite(jpg_saving_path, image)
    
    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Draw the bounding box on the result image
    cv2.rectangle(result_image, (new_x, new_y), (new_x + wn, new_y + hn), (0, 255, 0), 2)
    bounding_box_saving_path = jpg.replace("imagesO", "images_wbb")
    cv2.imwrite(bounding_box_saving_path, result_image)

    bbox_cord = [new_x,new_y,new_x+wn,new_y+hn]

    relative_center_x, relative_center_y, relative_width, relative_height = coordinates_to_percentage(bbox_cord,image_width,image_height)

    # Open a file for writing the results
    
    if classname not in unique_classes:
        unique_classes.append(classname)
    encoded_class = unique_classes.index(classname)
    with open(labels_save + filename + '.txt', 'w') as file:
        file.write(f"{encoded_class} {relative_center_x:.5f} {relative_center_y:.5f} {relative_width:.5f} {relative_height:.5f}")    

    pass

def apply_zoom(image,zoom_range):
    
    pass

def move_obj(image):

    pass

# %%
images_move = get_files_in_subdirectories(path_imgs,'.png')
unique_classes = []

for index, jpg in enumerate(images_move):
    filename = jpg.split('/')[-1].split('.')[0]
    classname = filename.split('_x')[0]

    # Load the image
    image = cv2.imread(jpg)

    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Perform edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours in the edge-detected image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Find the convex hull of the contours
    convex_hull = cv2.convexHull(np.vstack(contours))

    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Calculate the bounding box of the convex hull
    x, y, w, h = cv2.boundingRect(convex_hull)

    image_width = image.shape[1]
    image_height = image.shape[0] 

    aratio = w/h
    if aratio >= 1:
        px = 1
        py = int(1*aratio)
    else:
        px = int(1.0/aratio)
        py = 1
    x1 = x-px
    y1 = y-py
    x2 = x + w + px
    y2 = y + h + py
    wn = x2-x1
    hn = y2-y1
    w_reduce = 960
    h_reduce = 500
    # Calculate the maximum x and y coordinates for the new location
    max_x = image_width - w - int(w_reduce/2)
    max_y = image_height - h - int(h_reduce/2)

    # Generate random x and y coordinates for the new location
    new_x = np.random.randint(int(w_reduce/2), max_x + 1)
    new_y = np.random.randint(int(h_reduce/2), max_y + 1)
    if('asy' in classname):
        new_x = x1
        new_y = y1
    # Extract the object
    object_region = image[y1:y2, x1:x2].copy()

    # Paste the object into the new random location
    image[y1:y2, x1:x2] = [255, 255, 255]
    image[new_y:new_y+hn, new_x:new_x+wn] = object_region

    jpg_saving_path = jpg.replace("imagesO", "images")
    cv2.imwrite(jpg_saving_path, image)
    
    # Create a copy of the image for drawing the bounding box
    result_image = image.copy()

    # Draw the bounding box on the result image
    cv2.rectangle(result_image, (new_x, new_y), (new_x + wn, new_y + hn), (0, 255, 0), 2)
    bounding_box_saving_path = jpg.replace("imagesO", "images_wbb")
    cv2.imwrite(bounding_box_saving_path, result_image)

    bbox_cord = [new_x,new_y,new_x+wn,new_y+hn]

    relative_center_x, relative_center_y, relative_width, relative_height = coordinates_to_percentage(bbox_cord,image_width,image_height)

    # Open a file for writing the results
    
    if classname not in unique_classes:
        unique_classes.append(classname)
    encoded_class = unique_classes.index(classname)
    with open(labels_save + filename + '.txt', 'w') as file:
        file.write(f"{encoded_class} {relative_center_x:.5f} {relative_center_y:.5f} {relative_width:.5f} {relative_height:.5f}")

# %%
unique_classes
# Out:
# ['dst4', 'm4_10mm', 'din125_m4', 'm4_20mm', 'asy_m4_nut_screw_10mm']

# %% [markdown]
# ### Zoom augmentation with labels

# %%
def convert_jpg_to_png(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg"):
            # Open the JPG image
            jpg_path = os.path.join(input_folder, filename)
            img = Image.open(jpg_path)

            # Create the output PNG filename
            png_filename = os.path.splitext(filename)[0] + ".png"
            png_path = os.path.join(output_folder, png_filename)

            # Save the image in PNG format
            img.save(png_path, "PNG")
            os.remove(jpg_path)

            # print(f"Converted: {filename} -> {png_filename}")

def clean_name(input_folder,output_folder):

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        base_filename, file_extension = os.path.splitext(filename)
        name = base_filename.split("oom_")[0]+'oom'
        new_filename = name+file_extension
        old_path = os.path.join(input_folder, filename)
        new_path = os.path.join(output_folder, new_filename)
        os.rename(old_path, new_path)

def append_text_files(file1_path, file2_path):
    try:
        # Read the content of the second file
        with open(file2_path, 'r') as file2:
            content_to_append = '\n'+file2.read()

        # Append the content to the first file
        with open(file1_path, 'a') as file1:
            file1.write(content_to_append)

    except FileNotFoundError:
        print(f"File not found: {file2_path}")


def resize_and_place_object(image_path, original_bbox, scale_factor,future_path):

    # Crop the region inside the original bounding box
    x1, y1, x2, y2 = original_bbox
    ow = x2-x1
    oh = y2-y1
    # print(f'{y1} {y2} {x1} {x2}')
    w_reduce = 960
    h_reduce = 500

    original_image = cv2.imread(image_path)
    object_region = original_image[y1:y2, x1:x2].copy()
    new_w = int(scale_factor*(ow))
    new_h = int(scale_factor*(oh))
    if(scale_factor > 1 or scale_factor <1):
        resized_object = cv2.resize(object_region, (new_w,new_h))
    else:
        resized_object = object_region.copy()

    # print(f'h {new_h} w{new_w}')
    # Paste the object into the new random location
    original_image[y1:y2, x1:x2] = [255, 255, 255]

    # Calculate the maximum x and y coordinates for the new location
    max_x = original_image.shape[1] - new_w - int(w_reduce/2)
    max_y = original_image.shape[0] - new_h - int(h_reduce/2)

    # Generate random x and y coordinates for the new location
    new_x = np.random.randint(int(w_reduce/2), max_x + 1)
    new_y = np.random.randint(int(h_reduce/2), max_y + 1)
    original_image[new_y:new_y+new_h, new_x:new_x+new_w] = resized_object
    cv2.imwrite(future_path, original_image)

    image_path_save = future_path.replace('images','images_wbb')
    cv2.rectangle(original_image, (new_x, new_y), (new_w + new_x, new_h + new_y), (255, 0, 0), 2)
    cv2.imwrite(image_path_save, original_image)

    new_coords = [new_x,new_y]
    new_bbox = [new_x,new_y,new_w + new_x, new_h + new_y]

    return new_coords,new_bbox

def calculate_displaced_bbox(old_bbox,old_cords,new_cords,scale_factor,image_path):

    x1,y1,x2,y2 = old_bbox
    w = x2 - x1
    h = y2 - y1
    ox = old_cords[0]
    oy = old_cords[1]

    nx = new_cords[0]
    ny = new_cords[1]

    dist_vert_x = (x1 - ox)*scale_factor
    dist_vert_y = (y1 - oy)*scale_factor

    vert_x = nx + dist_vert_x
    vert_y = ny + dist_vert_y

    end_x = vert_x + w*scale_factor
    end_y = vert_y + h*scale_factor

    displaced_bbox = [vert_x,vert_y,end_x,end_y]
    displaced_bbox = [int(x) for x in displaced_bbox]
    
    image_path_save = image_path.replace('images','images_wbb')
    original_image = cv2.imread(image_path_save)
    cv2.rectangle(original_image, (int(vert_x), int(vert_y)), (int(end_x),int(end_y)), (0, 0, 255), 2)
    cv2.imwrite(image_path_save, original_image)

    return displaced_bbox

input_folder = "/Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/Assembly 3d/train/images/"
output_folder = "/Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/Assembly 3d/train/images2/"

# Labels
input_folder_l = "/Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/Assembly 3d/train/labels/"
output_folder_l = "/Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/Assembly 3d/train/labels2/"

# clean_name(input_folder, input_folder)
# convert_jpg_to_png(input_folder, input_folder)
# clean_name(input_folder_l, input_folder_l)

# %%
asy_images = [file for file in images_move if 'asy' in file]
len(asy_images)

data_path_threads =  data_path+'train_threads_b/'
path_assembly = data_path_threads + 'Assembly 3d/'
path_config = path_assembly+'data.yaml'
path_labels = 'Assembly 3d/train/labels/'

# Load YAML file
with open(path_config, 'r') as file:
    data = yaml.safe_load(file)

# Extract names from the YAML data
names = data.get('names', [])
# print(names)
zoom_range = [1,0.69,0.52]
zoom_names = ['z1oom','z2oom','z3oom']

# Create a mapping dictionary for the first list
mapping_dict = {value: index for index, value in enumerate(unique_classes)}


for index_1,image in enumerate(asy_images):
    print(image)
    label_1 = image.replace('imagesO','labels').replace('png','txt')  # Replace with the actual path to your first file
    label_2 = image.replace('imagesO',path_labels).replace('png','txt')  # Replace with the actual path to your second file
    append_text_files(label_1, label_2)

    original_image = Image.open(image)
    w,h = original_image.size

    # Read the content of the file and split it into lines
    with open(label_1, 'r') as file:
        lines = file.read().splitlines()

    # Convert each line to a list of floats
    bounding_boxes = [list(map(float, line.split())) for line in lines] # Labels

    for index_zoom, zoom in enumerate(zoom_range):

        result_bounding_boxes = []
        for index_bbox,bbox_l in enumerate(bounding_boxes):
            bbox_per = bbox_l[1:5]
            bbox_per = [round(element,4) for element in bbox_per]
            object_name = names[int(bbox_l[0])]
            object = mapping_dict[object_name]
            bbox = percentages_to_coordinates(bbox_per,w,h)
            print(f'zoom: {zoom}x bbox {object_name} : bbox {bbox}')
            # Zoom and move image
            if(index_bbox == 0):
                # print('zoom and move')
                save_path_i = image.replace(zoom_names[0],zoom_names[index_zoom]).replace('imagesO','images')
                # print(save_path_i)
                new_position,new_bbox = resize_and_place_object(image, bbox, zoom,save_path_i)
                # print(f'new cords: {new_position}')
                new_bbox_l = [object, new_bbox]
                result_bounding_boxes.append(new_bbox_l)
                old_cords = [bbox[0],bbox[1]]

            # Calculate new bounding boxes
            else:
                new_bbox = calculate_displaced_bbox(bbox,old_cords,new_position,zoom,save_path_i)
                new_bbox_l = [object,new_bbox]
                result_bounding_boxes.append(new_bbox_l)

        print(f'result bbox{result_bounding_boxes}')
        labels_path = image.replace('imagesO','labels').replace('png','txt').replace(zoom_names[0],zoom_names[index_zoom])
        with open(labels_path, 'w') as output_file:
            for index,item in enumerate(result_bounding_boxes):
                object = item[0]
                bbox = coordinates_to_percentage(item[1],1920,1080)
                if(index == len(result_bounding_boxes)-1):
                    line = f"{object} {bbox[0]:.5f} {bbox[1]:.5f} {bbox[2]:.5f} {bbox[3]:.5f}"
                else:
                    line = f"{object} {bbox[0]:.5f} {bbox[1]:.5f} {bbox[2]:.5f} {bbox[3]:.5f}\n"
                output_file.write(line)
# Out:
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-3_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (863, 450, 1064, 616)
# zoom: 1x bbox m4_10mm : bbox (862, 449, 1062, 611)
# zoom: 1x bbox dst4 : bbox (879, 492, 976, 611)
# result bbox[[4, [1238, 584, 1439, 750]], [1, [1237, 583, 1437, 745]], [0, [1254, 626, 1351, 745]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (863, 450, 1064, 616)
# zoom: 0.69x bbox m4_10mm : bbox (862, 449, 1062, 611)
# zoom: 0.69x bbox dst4 : bbox (879, 492, 976, 611)
# result bbox[[4, [906, 346, 1044, 460]], [1, [905, 345, 1043, 457]], [0, [917, 374, 983, 457]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (863, 450, 1064, 616)
# zoom: 0.52x bbox m4_10mm : bbox (862, 449, 1062, 611)
# zoom: 0.52x bbox dst4 : bbox (879, 492, 976, 611)
# result bbox[[4, [1078, 677, 1182, 763]], [1, [1077, 676, 1181, 760]], [0, [1086, 698, 1136, 760]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-1_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (888, 435, 1037, 639)
# zoom: 1x bbox m4_10mm : bbox (905, 432, 1042, 641)
# zoom: 1x bbox dst4 : bbox (884, 527, 1011, 607)
# result bbox[[4, [815, 398, 964, 602]], [1, [832, 395, 969, 604]], [0, [811, 490, 938, 570]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (888, 435, 1037, 639)
# zoom: 0.69x bbox m4_10mm : bbox (905, 432, 1042, 641)
# zoom: 0.69x bbox dst4 : bbox (884, 527, 1011, 607)
# result bbox[[4, [738, 273, 840, 413]], [1, [749, 270, 844, 415]], [0, [735, 336, 822, 391]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (888, 435, 1037, 639)
# zoom: 0.52x bbox m4_10mm : bbox (905, 432, 1042, 641)
# zoom: 0.52x bbox dst4 : bbox (884, 527, 1011, 607)
# result bbox[[4, [488, 439, 565, 545]], [1, [496, 437, 568, 546]], [0, [485, 486, 551, 528]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-2_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (873, 460, 1036, 610)
# zoom: 1x bbox m4_10mm : bbox (874, 460, 1011, 592)
# zoom: 1x bbox dst4 : bbox (917, 492, 1034, 609)
# result bbox[[4, [731, 560, 894, 710]], [1, [732, 560, 869, 692]], [0, [775, 592, 892, 709]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (873, 460, 1036, 610)
# zoom: 0.69x bbox m4_10mm : bbox (874, 460, 1011, 592)
# zoom: 0.69x bbox dst4 : bbox (917, 492, 1034, 609)
# result bbox[[4, [834, 690, 946, 793]], [1, [834, 690, 929, 781]], [0, [864, 712, 945, 792]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (873, 460, 1036, 610)
# zoom: 0.52x bbox m4_10mm : bbox (874, 460, 1011, 592)
# zoom: 0.52x bbox dst4 : bbox (917, 492, 1034, 609)
# result bbox[[4, [895, 620, 979, 698]], [1, [895, 620, 966, 688]], [0, [917, 636, 978, 697]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-4_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (878, 437, 1031, 644)
# zoom: 1x bbox m4_10mm : bbox (879, 435, 1016, 644)
# zoom: 1x bbox dst4 : bbox (907, 470, 1027, 544)
# result bbox[[4, [777, 277, 930, 484]], [1, [778, 275, 915, 484]], [0, [806, 310, 926, 384]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (878, 437, 1031, 644)
# zoom: 0.69x bbox m4_10mm : bbox (879, 435, 1016, 644)
# zoom: 0.69x bbox dst4 : bbox (907, 470, 1027, 544)
# result bbox[[4, [689, 397, 794, 539]], [1, [689, 395, 784, 539]], [0, [709, 419, 791, 470]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (878, 437, 1031, 644)
# zoom: 0.52x bbox m4_10mm : bbox (879, 435, 1016, 644)
# zoom: 0.52x bbox dst4 : bbox (907, 470, 1027, 544)
# result bbox[[4, [1287, 621, 1366, 728]], [1, [1287, 619, 1358, 728]], [0, [1302, 638, 1364, 676]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-3_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (865, 435, 1032, 616)
# zoom: 1x bbox m4_10mm : bbox (867, 432, 1024, 619)
# zoom: 1x bbox dst4 : bbox (915, 505, 1032, 609)
# result bbox[[4, [701, 306, 868, 487]], [1, [703, 303, 860, 490]], [0, [751, 376, 868, 480]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (865, 435, 1032, 616)
# zoom: 0.69x bbox m4_10mm : bbox (867, 432, 1024, 619)
# zoom: 0.69x bbox dst4 : bbox (915, 505, 1032, 609)
# result bbox[[4, [592, 329, 707, 453]], [1, [593, 326, 701, 455]], [0, [626, 377, 707, 449]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (865, 435, 1032, 616)
# zoom: 0.52x bbox m4_10mm : bbox (867, 432, 1024, 619)
# zoom: 0.52x bbox dst4 : bbox (915, 505, 1032, 609)
# result bbox[[4, [1287, 414, 1373, 508]], [1, [1288, 412, 1369, 509]], [0, [1313, 450, 1373, 504]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-0_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (896, 438, 1020, 642)
# zoom: 1x bbox m4_10mm : bbox (900, 437, 1024, 644)
# zoom: 1x bbox dst4 : bbox (899, 470, 1016, 539)
# result bbox[[4, [524, 460, 648, 664]], [1, [528, 459, 652, 666]], [0, [527, 492, 644, 561]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (896, 438, 1020, 642)
# zoom: 0.69x bbox m4_10mm : bbox (900, 437, 1024, 644)
# zoom: 0.69x bbox dst4 : bbox (899, 470, 1016, 539)
# result bbox[[4, [1239, 260, 1324, 400]], [1, [1241, 259, 1327, 402]], [0, [1241, 282, 1321, 329]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (896, 438, 1020, 642)
# zoom: 0.52x bbox m4_10mm : bbox (900, 437, 1024, 644)
# zoom: 0.52x bbox dst4 : bbox (899, 470, 1016, 539)
# result bbox[[4, [770, 448, 834, 554]], [1, [772, 447, 836, 555]], [0, [771, 464, 832, 500]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-1_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 1x bbox m4_10mm : bbox (857, 482, 1064, 599)
# zoom: 1x bbox m4_10mm : bbox (894, 477, 961, 601)
# result bbox[[4, [739, 516, 942, 639]], [1, [737, 520, 944, 637]], [1, [774, 515, 841, 639]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 0.69x bbox m4_10mm : bbox (857, 482, 1064, 599)
# zoom: 0.69x bbox m4_10mm : bbox (894, 477, 961, 601)
# result bbox[[4, [591, 347, 731, 431]], [1, [589, 349, 732, 430]], [1, [615, 346, 661, 431]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 0.52x bbox m4_10mm : bbox (857, 482, 1064, 599)
# zoom: 0.52x bbox m4_10mm : bbox (894, 477, 961, 601)
# result bbox[[4, [1153, 634, 1258, 697]], [1, [1151, 636, 1259, 696]], [1, [1171, 633, 1206, 697]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-4_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (857, 477, 1060, 600)
# zoom: 1x bbox m4_10mm : bbox (859, 474, 1059, 601)
# zoom: 1x bbox dst4 : bbox (957, 474, 1024, 601)
# result bbox[[4, [1201, 430, 1404, 553]], [1, [1203, 427, 1403, 554]], [0, [1301, 427, 1368, 554]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (857, 477, 1060, 600)
# zoom: 0.69x bbox m4_10mm : bbox (859, 474, 1059, 601)
# zoom: 0.69x bbox dst4 : bbox (957, 474, 1024, 601)
# result bbox[[4, [1195, 357, 1335, 441]], [1, [1196, 354, 1334, 442]], [0, [1264, 354, 1310, 442]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (857, 477, 1060, 600)
# zoom: 0.52x bbox m4_10mm : bbox (859, 474, 1059, 601)
# zoom: 0.52x bbox dst4 : bbox (957, 474, 1024, 601)
# result bbox[[4, [1020, 266, 1125, 329]], [1, [1021, 264, 1125, 330]], [0, [1072, 264, 1106, 330]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-2_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (884, 434, 1047, 638)
# zoom: 1x bbox m4_10mm : bbox (895, 427, 1052, 639)
# zoom: 1x bbox dst4 : bbox (887, 522, 1007, 606)
# result bbox[[4, [490, 590, 653, 794]], [1, [501, 583, 658, 795]], [0, [493, 678, 613, 762]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (884, 434, 1047, 638)
# zoom: 0.69x bbox m4_10mm : bbox (895, 427, 1052, 639)
# zoom: 0.69x bbox dst4 : bbox (887, 522, 1007, 606)
# result bbox[[4, [1254, 285, 1366, 425]], [1, [1261, 280, 1369, 426]], [0, [1256, 345, 1338, 403]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (884, 434, 1047, 638)
# zoom: 0.52x bbox m4_10mm : bbox (895, 427, 1052, 639)
# zoom: 0.52x bbox dst4 : bbox (887, 522, 1007, 606)
# result bbox[[4, [514, 408, 598, 514]], [1, [519, 404, 601, 514]], [0, [515, 453, 577, 497]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-3_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (876, 455, 1063, 609)
# zoom: 1x bbox m4_10mm : bbox (880, 455, 1062, 592)
# zoom: 1x bbox dst4 : bbox (884, 489, 986, 606)
# result bbox[[4, [770, 613, 957, 767]], [1, [774, 613, 956, 750]], [0, [778, 647, 880, 764]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (876, 455, 1063, 609)
# zoom: 0.69x bbox m4_10mm : bbox (880, 455, 1062, 592)
# zoom: 0.69x bbox dst4 : bbox (884, 489, 986, 606)
# result bbox[[4, [555, 622, 684, 728]], [1, [557, 622, 683, 716]], [0, [560, 645, 630, 726]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (876, 455, 1063, 609)
# zoom: 0.52x bbox m4_10mm : bbox (880, 455, 1062, 592)
# zoom: 0.52x bbox dst4 : bbox (884, 489, 986, 606)
# result bbox[[4, [951, 609, 1048, 689]], [1, [953, 609, 1047, 680]], [0, [955, 626, 1008, 687]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-0_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (893, 474, 1025, 605)
# zoom: 1x bbox m4_10mm : bbox (892, 474, 1024, 604)
# result bbox[[4, [557, 294, 689, 425]], [1, [556, 294, 688, 424]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (893, 474, 1025, 605)
# zoom: 0.69x bbox m4_10mm : bbox (892, 474, 1024, 604)
# result bbox[[4, [1325, 410, 1416, 500]], [1, [1324, 410, 1415, 499]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (893, 474, 1025, 605)
# zoom: 0.52x bbox m4_10mm : bbox (892, 474, 1024, 604)
# result bbox[[4, [839, 689, 907, 757]], [1, [838, 689, 907, 756]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-4_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 635)
# zoom: 1x bbox m4_10mm : bbox (865, 459, 1062, 633)
# zoom: 1x bbox dst4 : bbox (887, 460, 982, 579)
# result bbox[[4, [677, 597, 878, 770]], [1, [679, 594, 876, 768]], [0, [701, 595, 796, 714]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 635)
# zoom: 0.69x bbox m4_10mm : bbox (865, 459, 1062, 633)
# zoom: 0.69x bbox dst4 : bbox (887, 460, 982, 579)
# result bbox[[4, [1065, 619, 1203, 738]], [1, [1066, 616, 1202, 736]], [0, [1081, 617, 1147, 699]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 635)
# zoom: 0.52x bbox m4_10mm : bbox (865, 459, 1062, 633)
# zoom: 0.52x bbox dst4 : bbox (887, 460, 982, 579)
# result bbox[[4, [758, 699, 862, 788]], [1, [759, 697, 861, 787]], [0, [770, 697, 819, 759]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-0_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (902, 445, 1017, 626)
# zoom: 1x bbox m4_10mm : bbox (907, 447, 1014, 627)
# zoom: 1x bbox dst4 : bbox (897, 504, 1021, 614)
# result bbox[[4, [1187, 282, 1302, 463]], [1, [1192, 284, 1299, 464]], [0, [1182, 341, 1306, 451]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (902, 445, 1017, 626)
# zoom: 0.69x bbox m4_10mm : bbox (907, 447, 1014, 627)
# zoom: 0.69x bbox dst4 : bbox (897, 504, 1021, 614)
# result bbox[[4, [781, 454, 860, 578]], [1, [784, 455, 858, 579]], [0, [777, 494, 863, 570]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (902, 445, 1017, 626)
# zoom: 0.52x bbox m4_10mm : bbox (907, 447, 1014, 627)
# zoom: 0.52x bbox dst4 : bbox (897, 504, 1021, 614)
# result bbox[[4, [820, 647, 879, 741]], [1, [822, 648, 878, 741]], [0, [817, 677, 881, 734]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-3_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (861, 462, 1064, 628)
# zoom: 1x bbox m4_10mm : bbox (860, 467, 1067, 629)
# zoom: 1x bbox dst4 : bbox (879, 459, 976, 589)
# result bbox[[4, [818, 409, 1021, 575]], [1, [817, 414, 1024, 576]], [0, [836, 406, 933, 536]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (861, 462, 1064, 628)
# zoom: 0.69x bbox m4_10mm : bbox (860, 467, 1067, 629)
# zoom: 0.69x bbox dst4 : bbox (879, 459, 976, 589)
# result bbox[[4, [1159, 713, 1299, 827]], [1, [1158, 716, 1301, 828]], [0, [1171, 710, 1238, 800]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (861, 462, 1064, 628)
# zoom: 0.52x bbox m4_10mm : bbox (860, 467, 1067, 629)
# zoom: 0.52x bbox dst4 : bbox (879, 459, 976, 589)
# result bbox[[4, [1180, 665, 1285, 751]], [1, [1179, 667, 1287, 751]], [0, [1189, 663, 1239, 731]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-4_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (876, 436, 1030, 636)
# zoom: 1x bbox m4_10mm : bbox (877, 432, 1014, 634)
# zoom: 1x bbox dst4 : bbox (909, 524, 1029, 611)
# result bbox[[4, [1024, 263, 1178, 463]], [1, [1025, 259, 1162, 461]], [0, [1057, 351, 1177, 438]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (876, 436, 1030, 636)
# zoom: 0.69x bbox m4_10mm : bbox (877, 432, 1014, 634)
# zoom: 0.69x bbox dst4 : bbox (909, 524, 1029, 611)
# result bbox[[4, [1010, 590, 1116, 728]], [1, [1010, 587, 1105, 726]], [0, [1032, 650, 1115, 710]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (876, 436, 1030, 636)
# zoom: 0.52x bbox m4_10mm : bbox (877, 432, 1014, 634)
# zoom: 0.52x bbox dst4 : bbox (909, 524, 1029, 611)
# result bbox[[4, [871, 331, 951, 435]], [1, [871, 328, 942, 433]], [0, [888, 376, 950, 422]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-2_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (874, 460, 1064, 601)
# zoom: 1x bbox m4_10mm : bbox (877, 462, 1064, 594)
# zoom: 1x bbox dst4 : bbox (890, 490, 990, 597)
# result bbox[[4, [574, 335, 764, 476]], [1, [577, 337, 764, 469]], [0, [590, 365, 690, 472]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (874, 460, 1064, 601)
# zoom: 0.69x bbox m4_10mm : bbox (877, 462, 1064, 594)
# zoom: 0.69x bbox dst4 : bbox (890, 490, 990, 597)
# result bbox[[4, [618, 269, 749, 366]], [1, [620, 270, 749, 361]], [0, [629, 289, 698, 363]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (874, 460, 1064, 601)
# zoom: 0.52x bbox m4_10mm : bbox (877, 462, 1064, 594)
# zoom: 0.52x bbox dst4 : bbox (890, 490, 990, 597)
# result bbox[[4, [882, 291, 980, 364]], [1, [883, 292, 980, 360]], [0, [890, 306, 942, 362]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-1_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 464, 1051, 637)
# zoom: 1x bbox m4_10mm : bbox (854, 460, 1049, 640)
# zoom: 1x bbox dst4 : bbox (935, 462, 1037, 579)
# result bbox[[4, [551, 566, 747, 739]], [1, [550, 562, 745, 742]], [0, [631, 564, 733, 681]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 464, 1051, 637)
# zoom: 0.69x bbox m4_10mm : bbox (854, 460, 1049, 640)
# zoom: 0.69x bbox dst4 : bbox (935, 462, 1037, 579)
# result bbox[[4, [615, 709, 750, 828]], [1, [614, 706, 748, 830]], [0, [670, 707, 740, 788]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 464, 1051, 637)
# zoom: 0.52x bbox m4_10mm : bbox (854, 460, 1049, 640)
# zoom: 0.52x bbox dst4 : bbox (935, 462, 1037, 579)
# result bbox[[4, [797, 657, 898, 746]], [1, [796, 654, 897, 748]], [0, [838, 655, 891, 716]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-4_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (857, 479, 1060, 602)
# zoom: 1x bbox m4_10mm : bbox (857, 474, 1064, 604)
# zoom: 1x bbox dst4 : bbox (962, 477, 1021, 596)
# result bbox[[4, [775, 569, 978, 692]], [1, [775, 564, 982, 694]], [0, [880, 567, 939, 686]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox
z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 621)
# zoom: 1x bbox m4_10mm : bbox (857, 444, 1052, 621)
# zoom: 1x bbox dst4 : bbox (942, 502, 1029, 614)
# result bbox[[4, [540, 297, 737, 477]], [1, [542, 300, 737, 477]], [0, [627, 358, 714, 470]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 621)
# zoom: 0.69x bbox m4_10mm : bbox (857, 444, 1052, 621)
# zoom: 0.69x bbox dst4 : bbox (942, 502, 1029, 614)
# result bbox[[4, [1135, 480, 1270, 604]], [1, [1136, 482, 1270, 604]], [0, [1195, 522, 1255, 599]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 621)
# zoom: 0.52x bbox m4_10mm : bbox (857, 444, 1052, 621)
# zoom: 0.52x bbox dst4 : bbox (942, 502, 1029, 614)
# result bbox[[4, [1101, 524, 1203, 617]], [1, [1102, 525, 1203, 617]], [0, [1146, 555, 1191, 613]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-0_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (896, 437, 1020, 637)
# zoom: 1x bbox m4_10mm : bbox (902, 432, 1022, 636)
# zoom: 1x bbox dst4 : bbox (902, 537, 1009, 604)
# result bbox[[4, [610, 371, 734, 571]], [1, [616, 366, 736, 570]], [0, [616, 471, 723, 538]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (896, 437, 1020, 637)
# zoom: 0.69x bbox m4_10mm : bbox (902, 432, 1022, 636)
# zoom: 0.69x bbox dst4 : bbox (902, 537, 1009, 604)
# result bbox[[4, [1009, 655, 1094, 793]], [1, [1013, 651, 1095, 792]], [0, [1013, 724, 1086, 770]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (896, 437, 1020, 637)
# zoom: 0.52x bbox m4_10mm : bbox (902, 432, 1022, 636)
# zoom: 0.52x bbox dst4 : bbox (902, 537, 1009, 604)
# result bbox[[4, [490, 410, 554, 514]], [1, [493, 407, 555, 513]], [0, [493, 462, 548, 496]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-4_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (877, 442, 1030, 643)
# zoom: 1x bbox m4_10mm : bbox (879, 439, 1016, 643)
# zoom: 1x bbox m4_10mm : bbox (909, 465, 1033, 552)
# result bbox[[4, [933, 379, 1086, 580]], [1, [935, 376, 1072, 580]], [1, [965, 402, 1089, 489]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (877, 442, 1030, 643)
# zoom: 0.69x bbox m4_10mm : bbox (879, 439, 1016, 643)
# zoom: 0.69x bbox m4_10mm : bbox (909, 465, 1033, 552)
# result bbox[[4, [1014, 598, 1119, 736]], [1, [1015, 595, 1109, 736]], [1, [1036, 613, 1121, 673]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (877, 442, 1030, 643)
# zoom: 0.52x bbox m4_10mm : bbox (879, 439, 1016, 643)
# zoom: 0.52x bbox m4_10mm : bbox (909, 465, 1033, 552)
# result bbox[[4, [642, 595, 721, 699]], [1, [643, 593, 714, 699]], [1, [658, 606, 723, 652]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-3_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 471, 1060, 606)
# zoom: 1x bbox m4_10mm : bbox (857, 484, 1059, 608)
# zoom: 1x bbox dst4 : bbox (959, 472, 1024, 599)
# result bbox[[4, [695, 319, 900, 454]], [1, [697, 332, 899, 456]], [0, [799, 320, 864, 447]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 471, 1060, 606)
# zoom: 0.69x bbox m4_10mm : bbox (857, 484, 1059, 608)
# zoom: 0.69x bbox dst4 : bbox (959, 472, 1024, 599)
# result bbox[[4, [1149, 449, 1290, 542]], [1, [1150, 457, 1289, 543]], [0, [1220, 449, 1265, 537]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 471, 1060, 606)
# zoom: 0.52x bbox m4_10mm : bbox (857, 484, 1059, 608)
# zoom: 0.52x bbox dst4 : bbox (959, 472, 1024, 599)
# result bbox[[4, [717, 641, 823, 711]], [1, [718, 647, 823, 712]], [0, [771, 641, 804, 707]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-3_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (892, 448, 1031, 625)
# zoom: 1x bbox m4_10mm : bbox (892, 445, 1009, 625)
# zoom: 1x bbox dst4 : bbox (905, 492, 1032, 624)
# result bbox[[4, [562, 552, 701, 729]], [1, [562, 549, 679, 729]], [0, [575, 596, 702, 728]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (892, 448, 1031, 625)
# zoom: 0.69x bbox m4_10mm : bbox (892, 445, 1009, 625)
# zoom: 0.69x bbox dst4 : bbox (905, 492, 1032, 624)
# result bbox[[4, [580, 516, 675, 638]], [1, [580, 513, 660, 638]], [0, [588, 546, 676, 637]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (892, 448, 1031, 625)
# zoom: 0.52x bbox m4_10mm : bbox (892, 445, 1009, 625)
# zoom: 0.52x bbox dst4 : bbox (905, 492, 1032, 624)
# result bbox[[4, [611, 269, 683, 361]], [1, [611, 267, 671, 361]], [0, [617, 291, 683, 360]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-4_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 636)
# zoom: 1x bbox m4_10mm : bbox (864, 460, 1064, 640)
# zoom: 1x bbox dst4 : bbox (882, 467, 977, 574)
# result bbox[[4, [769, 578, 970, 752]], [1, [770, 576, 970, 756]], [0, [788, 583, 883, 690]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 636)
# zoom: 0.69x bbox m4_10mm : bbox (864, 460, 1064, 640)
# zoom: 0.69x bbox dst4 : bbox (882, 467, 977, 574)
# result bbox[[4, [958, 348, 1096, 468]], [1, [958, 346, 1096, 470]], [0, [971, 351, 1036, 425]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (863, 462, 1064, 636)
# zoom: 0.52x bbox m4_10mm : bbox (864, 460, 1064, 640)
# zoom: 0.52x bbox dst4 : bbox (882, 467, 977, 574)
# result bbox[[4, [1168, 336, 1272, 426]], [1, [1168, 334, 1272, 428]], [0, [1177, 338, 1227, 394]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-2_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (857, 453, 1049, 639)
# zoom: 1x bbox m4_10mm : bbox (857, 449, 1047, 638)
# zoom: 1x bbox dst4 : bbox (932, 459, 1037, 571)
# result bbox[[4, [561, 430, 753, 616]], [1, [561, 426, 751, 615]], [0, [636, 436, 741, 548]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (857, 453, 1049, 639)
# zoom: 0.69x bbox m4_10mm : bbox (857, 449, 1047, 638)
# zoom: 0.69x bbox dst4 : bbox (932, 459, 1037, 571)
# result bbox[[4, [848, 700, 980, 828]], [1, [848, 697, 979, 827]], [0, [899, 704, 972, 781]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (857, 453, 1049, 639)
# zoom: 0.52x bbox m4_10mm : bbox (857, 449, 1047, 638)
# zoom: 0.52x bbox dst4 : bbox (932, 459, 1037, 571)
# result bbox[[4, [751, 471, 850, 567]], [1, [751, 468, 849, 567]], [0, [790, 474, 844, 532]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-3_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (876, 469, 1064, 623)
# zoom: 1x bbox m4_10mm : bbox (879, 489, 1064, 621)
# zoom: 1x bbox dst4 : bbox (884, 472, 986, 589)
# result bbox[[4, [542, 371, 730, 525]], [1, [545, 391, 730, 523]], [0, [550, 374, 652, 491]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (876, 469, 1064, 623)
# zoom: 0.69x bbox m4_10mm : bbox (879, 489, 1064, 621)
# zoom: 0.69x bbox dst4 : bbox (884, 472, 986, 589)
# result bbox[[4, [765, 269, 894, 375]], [1, [767, 282, 894, 373]], [0, [770, 271, 840, 351]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (876, 469, 1064, 623)
# zoom: 0.52x bbox m4_10mm : bbox (879, 489, 1064, 621)
# zoom: 0.52x bbox dst4 : bbox (884, 472, 986, 589)
# result bbox[[4, [491, 527, 588, 607]], [1, [492, 537, 588, 606]], [0, [495, 528, 548, 589]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-4_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (866, 444, 1064, 620)
# zoom: 1x bbox m4_10mm : bbox (869, 437, 1064, 617)
# zoom: 1x bbox dst4 : bbox (880, 497, 985, 614)
# result bbox[[4, [729, 269, 927, 445]], [1, [732, 262, 927, 442]], [0, [743, 322, 848, 439]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (866, 444, 1064, 620)
# zoom: 0.69x bbox m4_10mm : bbox (869, 437, 1064, 617)
# zoom: 0.69x bbox dst4 : bbox (880, 497, 985, 614)
# result bbox[[4, [1050, 407, 1186, 528]], [1, [1052, 402, 1186, 526]], [0, [1059, 443, 1132, 524]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (866, 444, 1064, 620)
# zoom: 0.52x bbox m4_10mm : bbox (869, 437, 1064, 617)
# zoom: 0.52x bbox dst4 : bbox (880, 497, 985, 614)
# result bbox[[4, [484, 533, 586, 624]], [1, [485, 529, 586, 622]], [0, [491, 560, 545, 621]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-3_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 473, 1060, 608)
# zoom: 1x bbox m4_10mm : bbox (854, 472, 1061, 591)
# zoom: 1x bbox dst4 : bbox (957, 480, 1024, 607)
# result bbox[[4, [502, 594, 707, 729]], [1, [501, 593, 708, 712]], [0, [604, 601, 671, 728]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 473, 1060, 608)
# zoom: 0.69x bbox m4_10mm : bbox (854, 472, 1061, 591)
# zoom: 0.69x bbox dst4 : bbox (957, 480, 1024, 607)
# result bbox[[4, [515, 568, 656, 661]], [1, [514, 567, 657, 649]], [0, [585, 572, 631, 660]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 473, 1060, 608)
# zoom: 0.52x bbox m4_10mm : bbox (854, 472, 1061, 591)
# zoom: 0.52x bbox dst4 : bbox (957, 480, 1024, 607)
# result bbox[[4, [1267, 332, 1373, 402]], [1, [1266, 331, 1374, 393]], [0, [1320, 335, 1354, 401]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-1_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (886, 439, 1042, 643)
# zoom: 1x bbox m4_10mm : bbox (905, 437, 1042, 644)
# zoom: 1x bbox dst4 : bbox (887, 470, 1007, 544)
# result bbox[[4, [700, 416, 856, 620]], [1, [719, 414, 856, 621]], [0, [701, 447, 821, 521]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (886, 439, 1042, 643)
# zoom: 0.69x bbox m4_10mm : bbox (905, 437, 1042, 644)
# zoom: 0.69x bbox dst4 : bbox (887, 470, 1007, 544)
# result bbox[[4, [897, 566, 1004, 706]], [1, [910, 564, 1004, 707]], [0, [897, 587, 980, 638]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (886, 439, 1042, 643)
# zoom: 0.52x bbox m4_10mm : bbox (905, 437, 1042, 644)
# zoom: 0.52x bbox dst4 : bbox (887, 470, 1007, 544)
# result bbox[[4, [1078, 647, 1159, 753]], [1, [1087, 645, 1159, 753]], [0, [1078, 663, 1140, 701]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x
z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (872, 440, 1035, 645)
# zoom: 1x bbox m4_10mm : bbox (877, 437, 1024, 641)
# zoom: 1x bbox dst4 : bbox (909, 464, 1033, 553)
# result bbox[[4, [1031, 256, 1194, 461]], [1, [1036, 253, 1183, 457]], [0, [1068, 280, 1192, 369]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (872, 440, 1035, 645)
# zoom: 0.69x bbox m4_10mm : bbox (877, 437, 1024, 641)
# zoom: 0.69x bbox dst4 : bbox (909, 464, 1033, 553)
# result bbox[[4, [498, 656, 610, 797]], [1, [501, 653, 602, 794]], [0, [523, 672, 609, 733]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (872, 440, 1035, 645)
# zoom: 0.52x bbox m4_10mm : bbox (877, 437, 1024, 641)
# zoom: 0.52x bbox dst4 : bbox (909, 464, 1033, 553)
# result bbox[[4, [588, 311, 672, 417]], [1, [590, 309, 667, 415]], [0, [607, 323, 671, 369]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-4_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (881, 435, 1030, 639)
# zoom: 1x bbox m4_10mm : bbox (884, 430, 1016, 634)
# zoom: 1x bbox m4_10mm : bbox (909, 527, 1029, 611)
# result bbox[[4, [704, 324, 853, 528]], [1, [707, 319, 839, 523]], [1, [732, 416, 852, 500]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (881, 435, 1030, 639)
# zoom: 0.69x bbox m4_10mm : bbox (884, 430, 1016, 634)
# zoom: 0.69x bbox m4_10mm : bbox (909, 527, 1029, 611)
# result bbox[[4, [796, 286, 898, 426]], [1, [798, 282, 889, 423]], [1, [815, 349, 898, 407]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (881, 435, 1030, 639)
# zoom: 0.52x bbox m4_10mm : bbox (884, 430, 1016, 634)
# zoom: 0.52x bbox m4_10mm : bbox (909, 527, 1029, 611)
# result bbox[[4, [1334, 597, 1411, 703]], [1, [1335, 594, 1404, 700]], [1, [1348, 644, 1410, 688]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-4_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (868, 441, 1064, 621)
# zoom: 1x bbox m4_10mm : bbox (869, 442, 1064, 624)
# zoom: 1x bbox dst4 : bbox (880, 502, 985, 617)
# result bbox[[4, [899, 470, 1095, 650]], [1, [900, 471, 1095, 653]], [0, [911, 531, 1016, 646]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (868, 441, 1064, 621)
# zoom: 0.69x bbox m4_10mm : bbox (869, 442, 1064, 624)
# zoom: 0.69x bbox dst4 : bbox (880, 502, 985, 617)
# result bbox[[4, [736, 424, 871, 548]], [1, [736, 424, 871, 550]], [0, [744, 466, 816, 545]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (868, 441, 1064, 621)
# zoom: 0.52x bbox m4_10mm : bbox (869, 442, 1064, 624)
# zoom: 0.52x bbox dst4 : bbox (880, 502, 985, 617)
# result bbox[[4, [1249, 291, 1350, 384]], [1, [1249, 291, 1350, 386]], [0, [1255, 322, 1309, 382]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-2_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (854, 450, 1055, 616)
# zoom: 1x bbox m4_10mm : bbox (854, 447, 1056, 609)
# zoom: 1x bbox dst4 : bbox (947, 492, 1034, 611)
# result bbox[[4, [892, 293, 1093, 459]], [1, [892, 290, 1094, 452]], [0, [985, 335, 1072, 454]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (854, 450, 1055, 616)
# zoom: 0.69x bbox m4_10mm : bbox (854, 447, 1056, 609)
# zoom: 0.69x bbox dst4 : bbox (947, 492, 1034, 611)
# result bbox[[4, [481, 419, 619, 533]], [1, [481, 416, 620, 528]], [0, [545, 447, 605, 530]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (854, 450, 1055, 616)
# zoom: 0.52x bbox m4_10mm : bbox (854, 447, 1056, 609)
# zoom: 0.52x bbox dst4 : bbox (947, 492, 1034, 611)
# result bbox[[4, [1144, 331, 1248, 417]], [1, [1144, 329, 1249, 413]], [0, [1192, 352, 1237, 414]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-2_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1054, 617)
# zoom: 1x bbox m4_10mm : bbox (900, 432, 1052, 614)
# zoom: 1x bbox dst4 : bbox (889, 507, 1001, 611)
# result bbox[[4, [1251, 636, 1418, 818]], [1, [1264, 633, 1416, 815]], [0, [1253, 708, 1365, 812]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1054, 617)
# zoom: 0.69x bbox m4_10mm : bbox (900, 432, 1052, 614)
# zoom: 0.69x bbox dst4 : bbox (889, 507, 1001, 611)
# result bbox[[4, [1138, 669, 1253, 794]], [1, [1146, 666, 1251, 792]], [0, [1139, 718, 1216, 790]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1054, 617)
# zoom: 0.52x bbox m4_10mm : bbox (900, 432, 1052, 614)
# zoom: 0.52x bbox dst4 : bbox (889, 507, 1001, 611)
# result bbox[[4, [556, 464, 642, 558]], [1, [562, 462, 641, 557]], [0, [557, 501, 615, 555]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-4_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (868, 464, 1064, 637)
# zoom: 1x bbox m4_10mm : bbox (869, 464, 1064, 636)
# zoom: 1x bbox dst4 : bbox (887, 467, 984, 577)
# result bbox[[4, [1200, 655, 1396, 828]], [1, [1201, 655, 1396, 827]], [0, [1219, 658, 1316, 768]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (868, 464, 1064, 637)
# zoom: 0.69x bbox m4_10mm : bbox (869, 464, 1064, 636)
# zoom: 0.69x bbox dst4 : bbox (887, 467, 984, 577)
# result bbox[[4, [530, 288, 665, 407]], [1, [530, 288, 665, 406]], [0, [543, 290, 610, 365]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (868, 464, 1064, 637)
# zoom: 0.52x bbox m4_10mm : bbox (869, 464, 1064, 636)
# zoom: 0.52x bbox dst4 : bbox (887, 467, 984, 577)
# result bbox[[4, [1147, 305, 1248, 394]], [1, [1147, 305, 1248, 394]], [0, [1156, 306, 1207, 363]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-0_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (884, 449, 1058, 644)
# zoom: 1x bbox m4_10mm : bbox (887, 449, 1056, 644)
# zoom: 1x bbox dst4 : bbox (890, 462, 1000, 559)
# result bbox[[4, [617, 523, 791, 718]], [1, [620, 523, 789, 718]], [0, [623, 536, 733, 633]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (884, 449, 1058, 644)
# zoom: 0.69x bbox m4_10mm : bbox (887, 449, 1056, 644)
# zoom: 0.69x bbox dst4 : bbox (890, 462, 1000, 559)
# result bbox[[4, [1158, 520, 1278, 654]], [1, [1160, 520, 1276, 654]], [0, [1162, 528, 1238, 595]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (884, 449, 1058, 644)
# zoom: 0.52x bbox m4_10mm : bbox (887, 449, 1056, 644)
# zoom: 0.52x bbox dst4 : bbox (890, 462, 1000, 559)
# result bbox[[4, [585, 701, 675, 802]], [1, [586, 701, 674, 802]], [0, [588, 707, 645, 758]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-2_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 455, 1042, 609)
# zoom: 1x bbox m4_10mm : bbox (854, 455, 1044, 592)
# zoom: 1x bbox dst4 : bbox (939, 489, 1034, 606)
# result bbox[[4, [517, 534, 704, 688]], [1, [516, 534, 706, 671]], [0, [601, 568, 696, 685]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 455, 1042, 609)
# zoom: 0.69x bbox m4_10mm : bbox (854, 455, 1044, 592)
# zoom: 0.69x bbox dst4 : bbox (939, 489, 1034, 606)
# result bbox[[4, [1153, 340, 1282, 446]], [1, [1152, 340, 1283, 434]], [0, [1210, 363, 1276, 444]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 455, 1042, 609)
# zoom: 0.52x bbox m4_10mm : bbox (854, 455, 1044, 592)
# zoom: 0.52x bbox dst4 : bbox (939, 489, 1034, 606)
# result bbox[[4, [826, 559, 923, 639]], [1, [825, 559, 924, 630]], [0, [869, 576, 919, 637]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-1_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (892, 437, 1040, 642)
# zoom: 1x bbox m4_10mm : bbox (897, 435, 1039, 644)
# zoom: 1x bbox dst4 : bbox (892, 470, 1012, 547)
# result bbox[[4, [1031, 517, 1179, 722]], [1, [1036, 515, 1178, 724]], [0, [1031, 550, 1151, 627]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (892, 437, 1040, 642)
# zoom: 0.69x bbox m4_10mm : bbox (897, 435, 1039, 644)
# zoom: 0.69x bbox dst4 : bbox (892, 470, 1012, 547)
# result bbox[[4, [548, 442, 650, 583]], [1, [551, 440, 649, 584]], [0, [548, 464, 630, 517]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (892, 437, 1040, 642)
# zoom: 0.52x bbox m4_10mm : bbox (897, 435, 1039, 644)
# zoom: 0.52x bbox dst4 : bbox (892, 470, 1012, 547)
# result bbox[[4, [1344, 711, 1420, 817]], [1, [1346, 709, 1420, 818]], [0, [1344, 728, 1406, 768]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-2_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (854, 469, 1044, 623)
# zoom: 1x bbox m4_10mm : bbox (859, 487, 1044, 617)
# zoom: 1x bbox dst4 : bbox (935, 464, 1037, 591)
# result bbox[[4, [875, 362, 1065, 516]], [1, [880, 380, 1065, 510]], [0, [956, 357, 1058, 484]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (854, 469, 1044, 623)
# zoom: 0.69x bbox m4_10mm : bbox (859, 487, 1044, 617)
# zoom: 0.69x bbox dst4 : bbox (935, 464, 1037, 591)
# result bbox[[4, [1097, 671, 1228, 777]], [1, [1100, 683, 1228, 773]], [0, [1152, 667, 1223, 755]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (854, 469, 1044, 623)
# zoom: 0.52x bbox m4_10mm : bbox (859, 487, 1044, 617)
# zoom: 0.52x bbox dst4 : bbox (935, 464, 1037, 591)
# result bbox[[4, [956, 616, 1054, 696]], [1, [958, 625, 1054, 692]], [0, [998, 613, 1051, 679]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-2_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (859, 473, 1064, 608)
# zoom: 1x bbox m4_10mm : bbox (857, 467, 1067, 591)
# zoom: 1x bbox dst4 : bbox (890, 477, 960, 609)
# result bbox[[4, [738, 325, 943, 460]], [1, [736, 319, 946, 443]], [0, [769, 329, 839, 461]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (859, 473, 1064, 608)
# zoom: 0.69x bbox m4_10mm : bbox (857, 467, 1067, 591)
# zoom: 0.69x bbox dst4 : bbox (890, 477, 960, 609)
# result bbox[[4, [1231, 732, 1372, 825]], [1, [1229, 727, 1374, 813]], [0, [1252, 734, 1300, 825]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (859, 473, 1064, 608)
# zoom: 0.52x bbox m4_10mm : bbox (857, 467, 1067, 591)
# zoom: 0.52x bbox dst4 : bbox (890, 477, 960, 609)
# result bbox[[4, [1141, 558, 1247, 628]], [1, [1139, 554, 1249, 619]], [0, [1157, 560, 1193, 628]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-3_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (880, 468, 1046, 618)
# zoom: 1x bbox m4_10mm : bbox (890, 474, 1044, 613)
# zoom: 1x bbox dst4 : bbox (882, 467, 1006, 586)
# result bbox[[4, [1132, 545, 1298, 695]], [1, [1142, 551, 1296, 690]], [0, [1134, 544, 1258, 663]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (880, 468, 1046, 618)
# zoom: 0.69x bbox m4_10mm : bbox (890, 474, 1044, 613)
# zoom: 0.69x bbox dst4 : bbox (882, 467, 1006, 586)
# result bbox[[4, [1310, 499, 1424, 602]], [1, [1316, 503, 1423, 599]], [0, [1311, 498, 1396, 580]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (880, 468, 1046, 618)
# zoom: 0.52x bbox m4_10mm : bbox (890, 474, 1044, 613)
# zoom: 0.52x bbox dst4 : bbox (882, 467, 1006, 586)
# result bbox[[4, [720, 630, 806, 708]], [1, [725, 633, 805, 705]], [0, [721, 629, 785, 691]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-0_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (880, 453, 1034, 617)
# zoom: 1x bbox m4_10mm : bbox (882, 449, 1024, 616)
# zoom: 1x bbox dst4 : bbox (912, 499, 1029, 611)
# ...
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (872, 434, 1035, 638)
# zoom: 1x bbox m4_10mm : bbox (874, 430, 1026, 634)
# zoom: 1x bbox dst4 : bbox (917, 524, 1034, 606)
# result bbox[[4, [1085, 252, 1248, 456]], [1, [1087, 248, 1239, 452]], [0, [1130, 342, 1247, 424]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (872, 434, 1035, 638)
# zoom: 0.69x bbox m4_10mm : bbox (874, 430, 1026, 634)
# zoom: 0.69x bbox dst4 : bbox (917, 524, 1034, 606)
# result bbox[[4, [747, 367, 859, 507]], [1, [748, 364, 853, 505]], [0, [778, 429, 858, 485]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (872, 434, 1035, 638)
# zoom: 0.52x bbox m4_10mm : bbox (874, 430, 1026, 634)
# zoom: 0.52x bbox dst4 : bbox (917, 524, 1034, 606)
# result bbox[[4, [1325, 488, 1409, 594]], [1, [1326, 485, 1405, 592]], [0, [1348, 534, 1409, 577]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-2_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (863, 437, 1035, 615)
# zoom: 1x bbox m4_10mm : bbox (867, 437, 1026, 614)
# zoom: 1x bbox dst4 : bbox (914, 504, 1034, 614)
# result bbox[[4, [1091, 455, 1263, 633]], [1, [1095, 455, 1254, 632]], [0, [1142, 522, 1262, 632]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (863, 437, 1035, 615)
# zoom: 0.69x bbox m4_10mm : bbox (867, 437, 1026, 614)
# zoom: 0.69x bbox dst4 : bbox (914, 504, 1034, 614)
# result bbox[[4, [736, 410, 854, 532]], [1, [738, 410, 848, 532]], [0, [771, 456, 853, 532]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (863, 437, 1035, 615)
# zoom: 0.52x bbox m4_10mm : bbox (867, 437, 1026, 614)
# zoom: 0.52x bbox dst4 : bbox (914, 504, 1034, 614)
# result bbox[[4, [1144, 606, 1233, 698]], [1, [1146, 606, 1228, 698]], [0, [1170, 640, 1232, 698]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-1_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 1x bbox m4_10mm : bbox (862, 474, 1062, 604)
# zoom: 1x bbox dst4 : bbox (892, 472, 954, 599)
# result bbox[[4, [1083, 362, 1286, 485]], [1, [1086, 358, 1286, 488]], [0, [1116, 356, 1178, 483]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 0.69x bbox m4_10mm : bbox (862, 474, 1062, 604)
# zoom: 0.69x bbox dst4 : bbox (892, 472, 954, 599)
# result bbox[[4, [1296, 421, 1436, 505]], [1, [1298, 418, 1436, 507]], [0, [1318, 416, 1361, 504]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (859, 478, 1062, 601)
# zoom: 0.52x bbox m4_10mm : bbox (862, 474, 1062, 604)
# zoom: 0.52x bbox dst4 : bbox (892, 472, 954, 599)
# result bbox[[4, [581, 675, 686, 738]], [1, [582, 672, 686, 740]], [0, [598, 671, 630, 737]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-0_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (884, 452, 1038, 617)
# zoom: 1x bbox m4_10mm : bbox (895, 455, 1037, 614)
# zoom: 1x bbox dst4 : bbox (887, 497, 1007, 614)
# result bbox[[4, [611, 439, 765, 604]], [1, [622, 442, 764, 601]], [0, [614, 484, 734, 601]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (884, 452, 1038, 617)
# zoom: 0.69x bbox m4_10mm : bbox (895, 455, 1037, 614)
# zoom: 0.69x bbox dst4 : bbox (887, 497, 1007, 614)
# result bbox[[4, [1270, 369, 1376, 482]], [1, [1277, 371, 1375, 480]], [0, [1272, 400, 1354, 480]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (884, 452, 1038, 617)
# zoom: 0.52x bbox m4_10mm : bbox (895, 455, 1037, 614)
# zoom: 0.52x bbox dst4 : bbox (887, 497, 1007, 614)
# result bbox[[4, [1294, 361, 1374, 446]], [1, [1299, 362, 1373, 445]], [0, [1295, 384, 1357, 445]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-3_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (881, 460, 1045, 610)
# zoom: 1x bbox m4_10mm : bbox (890, 460, 1047, 602)
# zoom: 1x bbox dst4 : bbox (880, 492, 1000, 607)
# result bbox[[4, [1174, 674, 1338, 824]], [1, [1183, 674, 1340, 816]], [0, [1173, 706, 1293, 821]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (881, 460, 1045, 610)
# zoom: 0.69x bbox m4_10mm : bbox (890, 460, 1047, 602)
# zoom: 0.69x bbox dst4 : bbox (880, 492, 1000, 607)
# result bbox[[4, [625, 450, 738, 553]], [1, [631, 450, 739, 547]], [0, [624, 472, 707, 551]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (881, 460, 1045, 610)
# zoom: 0.52x bbox m4_10mm : bbox (890, 460, 1047, 602)
# zoom: 0.52x bbox dst4 : bbox (880, 492, 1000, 607)
# result bbox[[4, [1081, 642, 1166, 720]], [1, [1085, 642, 1167, 715]], [0, [1080, 658, 1142, 718]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-4_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (871, 440, 1064, 616)
# zoom: 1x bbox m4_10mm : bbox (875, 439, 1062, 616)
# zoom: 1x bbox dst4 : bbox (884, 497, 981, 612)
# result bbox[[4, [637, 328, 830, 504]], [1, [641, 327, 828, 504]], [0, [650, 385, 747, 500]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (871, 440, 1064, 616)
# zoom: 0.69x bbox m4_10mm : bbox (875, 439, 1062, 616)
# zoom: 0.69x bbox dst4 : bbox (884, 497, 981, 612)
# result bbox[[4, [991, 372, 1124, 493]], [1, [993, 371, 1122, 493]], [0, [999, 411, 1066, 490]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (871, 440, 1064, 616)
# zoom: 0.52x bbox m4_10mm : bbox (875, 439, 1062, 616)
# zoom: 0.52x bbox dst4 : bbox (884, 497, 981, 612)
# result bbox[[4, [1152, 294, 1252, 385]], [1, [1154, 293, 1251, 385]], [0, [1158, 323, 1209, 383]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-0_y-1_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (888, 442, 1041, 643)
# zoom: 1x bbox dst4 : bbox (889, 465, 1011, 557)
# zoom: 1x bbox m4_10mm : bbox (902, 442, 1041, 644)
# result bbox[[4, [531, 513, 684, 714]], [0, [532, 536, 654, 628]], [1, [545, 513, 684, 715]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (888, 442, 1041, 643)
# zoom: 0.69x bbox dst4 : bbox (889, 465, 1011, 557)
# zoom: 0.69x bbox m4_10mm : bbox (902, 442, 1041, 644)
# result bbox[[4, [853, 458, 958, 596]], [0, [853, 473, 937, 537]], [1, [862, 458, 958, 597]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (888, 442, 1041, 643)
# zoom: 0.52x bbox dst4 : bbox (889, 465, 1011, 557)
# zoom: 0.52x bbox m4_10mm : bbox (902, 442, 1041, 644)
# result bbox[[4, [967, 533, 1046, 637]], [0, [967, 544, 1030, 592]], [1, [974, 533, 1046, 638]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-0_z-2_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (861, 451, 1037, 644)
# zoom: 1x bbox m4_10mm : bbox (867, 450, 1036, 642)
# zoom: 1x bbox dst4 : bbox (927, 464, 1034, 561)
# result bbox[[4, [1123, 434, 1299, 627]], [1, [1129, 433, 1298, 625]], [0, [1189, 447, 1296, 544]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (861, 451, 1037, 644)
# zoom: 0.69x bbox m4_10mm : bbox (867, 450, 1036, 642)
# zoom: 0.69x bbox dst4 : bbox (927, 464, 1034, 561)
# result bbox[[4, [659, 361, 780, 494]], [1, [663, 360, 779, 492]], [0, [704, 369, 778, 436]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (861, 451, 1037, 644)
# zoom: 0.52x bbox m4_10mm : bbox (867, 450, 1036, 642)
# zoom: 0.52x bbox dst4 : bbox (927, 464, 1034, 561)
# result bbox[[4, [1141, 541, 1232, 641]], [1, [1144, 540, 1232, 640]], [0, [1175, 547, 1230, 598]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-2_z-0_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (890, 434, 1029, 639)
# zoom: 1x bbox m4_10mm : bbox (909, 430, 1019, 637)
# zoom: 1x bbox dst4 : bbox (892, 532, 1019, 606)
# result bbox[[4, [762, 328, 901, 533]], [1, [781, 324, 891, 531]], [0, [764, 426, 891, 500]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (890, 434, 1029, 639)
# zoom: 0.69x bbox m4_10mm : bbox (909, 430, 1019, 637)
# zoom: 0.69x bbox dst4 : bbox (892, 532, 1019, 606)
# result bbox[[4, [1025, 378, 1120, 519]], [1, [1038, 375, 1114, 518]], [0, [1026, 445, 1114, 496]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (890, 434, 1029, 639)
# zoom: 0.52x bbox m4_10mm : bbox (909, 430, 1019, 637)
# zoom: 0.52x bbox dst4 : bbox (892, 532, 1019, 606)
# result bbox[[4, [916, 526, 988, 632]], [1, [925, 523, 983, 631]], [0, [917, 576, 983, 615]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-4_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (876, 435, 1032, 639)
# zoom: 1x bbox m4_10mm : bbox (874, 432, 1016, 636)
# zoom: 1x bbox dst4 : bbox (912, 534, 1032, 606)
# result bbox[[4, [587, 473, 743, 677]], [1, [585, 470, 727, 674]], [0, [623, 572, 743, 644]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (876, 435, 1032, 639)
# zoom: 0.69x bbox m4_10mm : bbox (874, 432, 1016, 636)
# zoom: 0.69x bbox dst4 : bbox (912, 534, 1032, 606)
# result bbox[[4, [1024, 493, 1131, 633]], [1, [1022, 490, 1120, 631]], [0, [1048, 561, 1131, 610]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (876, 435, 1032, 639)
# zoom: 0.52x bbox m4_10mm : bbox (874, 432, 1016, 636)
# zoom: 0.52x bbox dst4 : bbox (912, 534, 1032, 606)
# result bbox[[4, [1123, 409, 1204, 515]], [1, [1121, 407, 1195, 513]], [0, [1141, 460, 1204, 497]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-1_y-1_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 462, 1056, 638)
# zoom: 1x bbox m4_10mm : bbox (857, 459, 1054, 633)
# zoom: 1x bbox dst4 : bbox (940, 464, 1037, 576)
# result bbox[[4, [1167, 292, 1368, 468]], [1, [1169, 289, 1366, 463]], [0, [1252, 294, 1349, 406]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 462, 1056, 638)
# zoom: 0.69x bbox m4_10mm : bbox (857, 459, 1054, 633)
# zoom: 0.69x bbox dst4 : bbox (940, 464, 1037, 576)
# result bbox[[4, [1231, 420, 1369, 541]], [1, [1232, 417, 1368, 537]], [0, [1289, 421, 1356, 498]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 462, 1056, 638)
# zoom: 0.52x bbox m4_10mm : bbox (857, 459, 1054, 633)
# zoom: 0.52x bbox dst4 : bbox (940, 464, 1037, 576)
# result bbox[[4, [818, 398, 922, 489]], [1, [819, 396, 921, 486]], [0, [862, 399, 912, 457]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-3_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (869, 454, 1061, 639)
# zoom: 1x bbox m4_10mm : bbox (872, 452, 1059, 639)
# zoom: 1x bbox dst4 : bbox (882, 465, 992, 569)
# result bbox[[4, [688, 276, 880, 461]], [1, [691, 274, 878, 461]], [0, [701, 287, 811, 391]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (869, 454, 1061, 639)
# zoom: 0.69x bbox m4_10mm : bbox (872, 452, 1059, 639)
# zoom: 0.69x bbox dst4 : bbox (882, 465, 992, 569)
# result bbox[[4, [512, 472, 644, 599]], [1, [514, 470, 643, 599]], [0, [520, 479, 596, 551]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (869, 454, 1061, 639)
# zoom: 0.52x bbox m4_10mm : bbox (872, 452, 1059, 639)
# zoom: 0.52x bbox dst4 : bbox (882, 465, 992, 569)
# result bbox[[4, [723, 501, 822, 597]], [1, [724, 499, 821, 597]], [0, [729, 506, 786, 560]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-1_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (854, 445, 1052, 619)
# zoom: 1x bbox m4_10mm : bbox (857, 445, 1054, 617)
# zoom: 1x bbox dst4 : bbox (940, 499, 1027, 614)
# result bbox[[4, [757, 568, 955, 742]], [1, [760, 568, 957, 740]], [0, [843, 622, 930, 737]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (854, 445, 1052, 619)
# zoom: 0.69x bbox m4_10mm : bbox (857, 445, 1054, 617)
# zoom: 0.69x bbox dst4 : bbox (940, 499, 1027, 614)
# result bbox[[4, [1257, 425, 1393, 545]], [1, [1259, 425, 1395, 543]], [0, [1316, 462, 1376, 541]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (854, 445, 1052, 619)
# zoom: 0.52x bbox m4_10mm : bbox (857, 445, 1054, 617)
# zoom: 0.52x bbox dst4 : bbox (940, 499, 1027, 614)
# result bbox[[4, [996, 488, 1098, 578]], [1, [997, 488, 1100, 577]], [0, [1040, 516, 1085, 575]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-2_y-4_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 478, 1060, 601)
# zoom: 1x bbox m4_10mm : bbox (854, 475, 1064, 599)
# zoom: 1x bbox m4_10mm : bbox (959, 477, 1024, 596)
# result bbox[[4, [851, 352, 1056, 475]], [1, [850, 349, 1060, 473]], [1, [955, 351, 1020, 470]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 478, 1060, 601)
# zoom: 0.69x bbox m4_10mm : bbox (854, 475, 1064, 599)
# zoom: 0.69x bbox m4_10mm : bbox (959, 477, 1024, 596)
# result bbox[[4, [1272, 307, 1413, 391]], [1, [1271, 304, 1416, 390]], [1, [1343, 306, 1388, 388]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 478, 1060, 601)
# zoom: 0.52x bbox m4_10mm : bbox (854, 475, 1064, 599)
# zoom: 0.52x bbox m4_10mm : bbox (959, 477, 1024, 596)
# result bbox[[4, [923, 479, 1029, 542]], [1, [922, 477, 1031, 541]], [1, [977, 478, 1010, 540]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-1_z-4_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1040, 639)
# zoom: 1x bbox m4_10mm : bbox (895, 434, 1042, 636)
# zoom: 1x bbox dst4 : bbox (887, 527, 1009, 609)
# result bbox[[4, [1057, 402, 1210, 606]], [1, [1065, 401, 1212, 603]], [0, [1057, 494, 1179, 576]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1040, 639)
# zoom: 0.69x bbox m4_10mm : bbox (895, 434, 1042, 636)
# zoom: 0.69x bbox dst4 : bbox (887, 527, 1009, 609)
# result bbox[[4, [645, 587, 750, 727]], [1, [650, 586, 751, 725]], [0, [645, 650, 729, 707]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (887, 435, 1040, 639)
# zoom: 0.52x bbox m4_10mm : bbox (895, 434, 1042, 636)
# zoom: 0.52x bbox dst4 : bbox (887, 527, 1009, 609)
# result bbox[[4, [532, 646, 611, 752]], [1, [536, 645, 612, 750]], [0, [532, 693, 595, 736]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-4_y-1_z-1_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 618)
# zoom: 1x bbox m4_10mm : bbox (852, 437, 1052, 617)
# zoom: 1x bbox dst4 : bbox (937, 499, 1032, 609)
# result bbox[[4, [857, 345, 1054, 522]], [1, [854, 341, 1054, 521]], [0, [939, 403, 1034, 513]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 618)
# zoom: 0.69x bbox m4_10mm : bbox (852, 437, 1052, 617)
# zoom: 0.69x bbox dst4 : bbox (937, 499, 1032, 609)
# result bbox[[4, [1178, 258, 1313, 380]], [1, [1175, 255, 1313, 379]], [0, [1234, 298, 1300, 373]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (855, 441, 1052, 618)
# zoom: 0.52x bbox m4_10mm : bbox (852, 437, 1052, 617)
# zoom: 0.52x bbox dst4 : bbox (937, 499, 1032, 609)
# result bbox[[4, [1150, 291, 1252, 383]], [1, [1148, 288, 1252, 382]], [0, [1192, 321, 1242, 378]]]
# /Users/rodolfocacacho/Documents/Documents/MAI/Project module/3d_mai/data/train_threads_b/imagesO/asy_m4_nut_screw_10mm_x-3_y-4_z-3_z-z1oom.png
# zoom: 1x bbox asy_m4_nut_screw_10mm : bbox (881, 437, 1030, 644)
# zoom: 1x bbox m4_10mm : bbox (879, 435, 1011, 647)
# zoom: 1x bbox dst4 : bbox (900, 467, 1032, 551)
# result bbox[[4, [958, 580, 1107, 787]], [1, [956, 578, 1088, 790]], [0, [977, 610, 1109, 694]]]
# zoom: 0.69x bbox asy_m4_nut_screw_10mm : bbox (881, 437, 1030, 644)
# zoom: 0.69x bbox m4_10mm : bbox (879, 435, 1011, 647)
# zoom: 0.69x bbox dst4 : bbox (900, 467, 1032, 551)
# result bbox[[4, [1279, 396, 1381, 538]], [1, [1277, 394, 1368, 540]], [0, [1292, 416, 1383, 474]]]
# zoom: 0.52x bbox asy_m4_nut_screw_10mm : bbox (881, 437, 1030, 644)
# zoom: 0.52x bbox m4_10mm : bbox (879, 435, 1011, 647)
# zoom: 0.52x bbox dst4 : bbox (900, 467, 1032, 551)
# result bbox[[4, [560, 709, 637, 816]], [1, [558, 707, 627, 818]], [0, [569, 724, 638, 768]]]

# %% [markdown]
# ### Move images into train and test folder

# %%
unique_classes = ['dst4', 'm4_10mm', 'din125_m4', 'm4_20mm', 'asy_m4_nut_screw_10mm']

# %%
def delete_and_create_folder(folder_path, subdirectories=None):
    try:
        # Check if the folder exists
        if os.path.exists(folder_path):
            # Delete existing folder and its contents
            for root, dirs, files in os.walk(folder_path, topdown=False):
                for file_name in files:
                    file_path = os.path.join(root, file_name)
                    os.remove(file_path)
                for dir_name in dirs:
                    dir_path = os.path.join(root, dir_name)
                    os.rmdir(dir_path)
            os.rmdir(folder_path)
            # print(f"Existing folder '{folder_path}' deleted successfully.")

        # Create a new empty folder
        os.makedirs(folder_path)
        # print(f"New empty folder '{folder_path}' created successfully.")

        # Create subdirectories if specified
        if subdirectories:
            for subdirectory_info in subdirectories:
                subdirectory_name = subdirectory_info["name"]
                subdirectory_path = os.path.join(folder_path, subdirectory_name)
                os.makedirs(subdirectory_path)
                # print(f"Subdirectory '{subdirectory_path}' created.")

                # Recursively create nested subdirectories
                nested_subdirectories = subdirectory_info.get("subdirectories", [])
                if nested_subdirectories:
                    nested_path = subdirectory_path
                    delete_and_create_folder(nested_path, nested_subdirectories)
    except OSError as e:
        print(f"Error: {folder_path} - {e.strerror}")

def copy_file(source_file, destination_directory):
    try:
        # Ensure the destination directory exists
        os.makedirs(destination_directory, exist_ok=True)

        # Extract the file name from the source file path
        file_name = os.path.basename(source_file)

        # Create the destination file path
        destination_file = os.path.join(destination_directory, file_name)

        # Copy the file
        with open(source_file, 'rb') as source, open(destination_file, 'wb') as destination:
            destination.write(source.read())

        print(f"File '{source_file}' copied to '{destination_file}' successfully.")
    except IOError as e:
        print(f"Error: {e}")

# %%
data_path = parent_dir+'/data/'
path_imgs = data_path+'train_threads_b/images/'
images = get_files_in_subdirectories(path_imgs,'.png')
path_train_val = data_path+'train_threads_b/object_train_val/'
subdirs = ['train','validation']
# Example usage with nested subdirectories
subdirs = [
    {"name": "train", "subdirectories": [{"name": "images"}, {"name": "labels"}]},
    {"name": "validation", "subdirectories": [{"name": "images"}, {"name": "labels"}]}
]
delete_and_create_folder(path_train_val,subdirs)
percentage_train = 80

for index,class_obj in enumerate(unique_classes):
    images_search = [file for file in images if class_obj in file]
    train_val = create_binary_list(len(images_search),percentage_train)
    train = 0
    print(f'class {class_obj}')
    for index_i,image in enumerate(images_search):
        path_label = image.replace('images','labels').replace('png','txt')
        if(train_val[index_i] == 1): #training
            path_save_image = path_train_val+'train/images'
            path_save_label = path_train_val+'train/labels'
