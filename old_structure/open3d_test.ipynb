# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import copy
import os
import re

# %%
def get_subdirectories(folder_path):
    subdirectories = []
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if os.path.isdir(item_path):
            subdirectories.append(item)
    return subdirectories

def get_files_in_subdirectories(folder_path, file_extension='', file_contains=''):
    files = []
    for root, directories, filenames in os.walk(folder_path):
        for filename in filenames:
            if file_extension == '' and file_contains == '':
                files.append(os.path.join(root, filename))
            elif file_extension != '' and file_contains == '':
                if filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
            elif file_extension == '' and file_contains != '':
                if file_contains in filename:
                    files.append(os.path.join(root, filename))
            else:
                if file_contains in filename and filename.endswith(file_extension):
                    files.append(os.path.join(root, filename))
    return files


def extract_string(filename,format = 'stl'):
    pattern = r'\/([^/]+)\.'+format+'$'
    match = re.search(pattern, filename)
    if match:
        return match.group(1)
    else:
        return None
    
# Defining a function to convert degrees to radians.
def deg2rad(deg):
    return deg * np.pi/180

def get_rotated_pcd(pcd, x_theta, y_theta, z_theta):
    pcd_rotated = copy.deepcopy(pcd)
    R = pcd_rotated.get_rotation_matrix_from_axis_angle([x_theta, y_theta, z_theta])
    pcd_rotated.rotate(R, center=(0, 0, 0))
    return pcd_rotated

def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
        return False
    else:
        print(f"Folder already exists: {folder_path}")
        return True

def delete_file(file_path):
    try:
        os.remove(file_path)
        # print(f"File '{file_path}' deleted successfully.")
    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
    except PermissionError:
        print(f"Permission denied: unable to delete file '{file_path}'.")
    except Exception as e:
        print(f"An error occurred while deleting the file: {e}")

# %%
parts_path = os.getcwd()+'/Parts/'
file_extension = '.stl'
save_path = os.getcwd()+'/Screenshots/'

files = get_files_in_subdirectories(parts_path,file_extension)


for i in files:

    print("Testing IO for meshes ...")
    name_part = extract_string(i)
    print(name_part)
    path_save = save_path+name_part+'/'
    exists = create_folder_if_not_exists(path_save)
    if exists:
        images_del = get_files_in_subdirectories(path_save,'jpg')
        for imdel in images_del:
            delete_file(imdel)

    mesh = o3d.io.read_triangle_mesh(i)
    mesh.compute_vertex_normals()
    print(mesh)

    # Defining the steps and range of angle values by which to rotate the point cloud.
    theta_range = np.linspace(-180, 180, 8)

    # Counting the number of sequential operations.
    view_counter = 1
    total_views = theta_range.shape[0] ** 3

    i = 0
    j = 0
    k = 0
    # Looping through the angle values defined above for each axis.
    for x_theta_deg in theta_range:
        j = 0
        for y_theta_deg in theta_range:
            i = 0
            for z_theta_deg in theta_range:
                print(f"Taking image {view_counter} of {total_views}.")

                # Rotating the point cloud by the given angle values.
                x_theta = deg2rad(x_theta_deg)
                y_theta = deg2rad(y_theta_deg)
                z_theta = deg2rad(z_theta_deg)
                pcd_rotated = get_rotated_pcd(mesh, x_theta, y_theta, z_theta)

                # draw_geoms_list = [pcd_rotated]

                vis = o3d.visualization.Visualizer()
                vis.create_window(visible=False)
                # vis.add_geometry(mesh)
                vis.add_geometry(pcd_rotated)

                # R = mesh.get_rotation_matrix_from_xyz((angle_vector[i],angle_vector[j],angle_vector[k]))
                # mesh.rotate(R, center=(0, 0, 0))
                
                vis.poll_events()
                vis.update_renderer()
                #vis.reset_view_point()
                name_ijk = str(i)+'_'+str(j)+'_'+str(k)
                vis.capture_screen_image(filename = path_save+'test_'+name_ijk+'.jpg')

                # o3d.visualization.draw_geometries(draw_geoms_list)
                view_counter += 1
                i +=1
            j +=1
        k+=1
    vis.destroy_window()
# Out:
# Testing IO for meshes ...
# 622184x10
# Folder already exists: /Users/rodolfocacacho/Documents/Documents/MAI/1.Semester/Project Module/3d_mai/Screenshots/622184x10/
# TriangleMesh with 616 points and 344 triangles.
# Taking image 1 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 2 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 3 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 4 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 5 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 6 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 7 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 8 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 9 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 10 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 11 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 12 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 13 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 14 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 15 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 16 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 17 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 18 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 19 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 20 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 21 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 22 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 23 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 24 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 25 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 26 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 27 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 28 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 29 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 30 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 31 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 32 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 33 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 34 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 35 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 36 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 37 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 38 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 39 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 40 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 41 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 42 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 43 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 44 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 45 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 46 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 47 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 48 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 49 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 50 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 51 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 52 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 53 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 54 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 55 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 56 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 57 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 58 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 59 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 60 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 61 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 62 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 63 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 64 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 65 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 66 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 67 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 68 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 69 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 70 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 71 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 72 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 73 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 74 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 75 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 76 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 77 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 78 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 79 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 80 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 81 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 82 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 83 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 84 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 85 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 86 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 87 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 88 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 89 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 90 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 91 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 92 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 93 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 94 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 95 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 96 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 97 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 98 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 99 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 100 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 101 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 102 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 103 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 104 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 105 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 106 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 107 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 108 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 109 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 110 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 111 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 112 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 113 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 114 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 115 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 116 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 117 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 118 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 119 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 120 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 121 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 122 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 123 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 124 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 125 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 126 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 127 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 128 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 129 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 130 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 131 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 132 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 133 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 134 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 135 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 136 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 137 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 138 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 139 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 140 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 141 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 142 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 143 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 144 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 145 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 146 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 147 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 148 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 149 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 150 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 151 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 152 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 153 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 154 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 155 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 156 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 157 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 158 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 159 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 160 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 161 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 162 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 163 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 164 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 165 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 166 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 167 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 168 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 169 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 170 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 171 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 172 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 173 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 174 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 175 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 176 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 177 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 178 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 179 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 180 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 181 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 182 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 183 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 184 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 185 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 186 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 187 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 188 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 189 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 190 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 191 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 192 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 193 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 194 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 195 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 196 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 197 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 198 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 199 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 200 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 201 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 202 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 203 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 204 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 205 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 206 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 207 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 208 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 209 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 210 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 211 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 212 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 213 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 214 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 215 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 216 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 217 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 218 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 219 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 220 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 221 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 222 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 223 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 224 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 225 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 226 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 227 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 228 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 229 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 230 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 231 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 232 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 233 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 234 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 235 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 236 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 237 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 238 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 239 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 240 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 241 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 242 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 243 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 244 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 245 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 246 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 247 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 248 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 249 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 250 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 251 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 252 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 253 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 254 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 255 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 256 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 257 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 258 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 259 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 260 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 261 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 262 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 263 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 264 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 265 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 266 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 267 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 268 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 269 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 270 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 271 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 272 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 273 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 274 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 275 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 276 of 512.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image

# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
print("Testing IO for meshes ...")
mesh = o3d.io.read_triangle_mesh(file_path)
mesh.compute_vertex_normals()
print(mesh)
# Out:
# Testing IO for meshes ...
# TriangleMesh with 7752 points and 2768 triangles.

# %%
def get_rotated_pcd(pcd, x_theta, y_theta, z_theta):
    pcd_rotated = copy.deepcopy(pcd)
    R = pcd_rotated.get_rotation_matrix_from_axis_angle([x_theta, y_theta, z_theta])
    pcd_rotated.rotate(R, center=(0, 0, 0))
    return pcd_rotated

# Defining a function to convert degrees to radians.
def deg2rad(deg):
    return deg * np.pi/180

# %%
# Performing the hidden point removal operation sequentially by rotating the
# point cloud slightly in each of the three axes from -90 to +90 degrees,
# and aggregating the list of indexes of points that are not hidden after
# each operation.

# Defining a list to store the aggregated output lists from each hidden
# point removal operation.

# Defining the steps and range of angle values by which to rotate the point cloud.
theta_range = np.linspace(-180, 180, 5)

# Counting the number of sequential operations.
view_counter = 1
total_views = theta_range.shape[0] ** 3

i = 0
j = 0
k = 0
# Looping through the angle values defined above for each axis.
for x_theta_deg in theta_range:
    j = 0
    for y_theta_deg in theta_range:
        i = 0
        for z_theta_deg in theta_range:
            print(f"Taking image {view_counter} of {total_views}.")

            # Rotating the point cloud by the given angle values.
            x_theta = deg2rad(x_theta_deg)
            y_theta = deg2rad(y_theta_deg)
            z_theta = deg2rad(z_theta_deg)
            pcd_rotated = get_rotated_pcd(mesh, x_theta, y_theta, z_theta)

            # draw_geoms_list = [pcd_rotated]

            vis = o3d.visualization.Visualizer()
            vis.create_window(visible=False)
            # vis.add_geometry(mesh)
            vis.add_geometry(pcd_rotated)

            # R = mesh.get_rotation_matrix_from_xyz((angle_vector[i],angle_vector[j],angle_vector[k]))
            # mesh.rotate(R, center=(0, 0, 0))
            
            vis.poll_events()
            vis.update_renderer()
            #vis.reset_view_point()
            name_ijk = str(i)+'_'+str(j)+'_'+str(k)
            vis.capture_screen_image(filename = 'screenshots/test_'+name_ijk+'.jpg')

            # o3d.visualization.draw_geometries(draw_geoms_list)
            view_counter += 1
            i +=1
        j +=1
    k+=1
vis.destroy_window()
# Out:
# Taking image 1 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 2 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 3 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 4 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 5 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 6 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 7 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 8 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 9 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 10 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 11 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 12 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 13 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 14 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 15 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 16 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 17 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 18 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 19 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 20 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 21 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 22 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 23 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 24 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 25 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 26 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 27 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 28 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 29 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 30 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 31 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 32 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 33 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 34 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 35 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 36 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 37 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 38 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 39 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 40 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 41 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 42 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 43 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 44 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 45 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 46 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 47 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 48 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 49 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 50 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 51 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 52 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 53 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 54 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 55 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 56 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 57 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 58 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 59 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 60 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 61 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 62 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 63 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 64 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 65 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 66 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 67 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 68 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 69 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 70 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 71 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 72 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 73 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 74 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 75 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 76 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 77 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 78 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 79 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 80 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 81 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 82 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 83 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 84 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 85 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 86 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 87 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 88 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 89 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 90 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 91 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 92 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 93 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 94 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 95 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 96 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 97 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 98 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 99 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 100 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 101 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 102 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 103 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 104 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 105 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 106 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 107 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 108 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 109 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 110 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 111 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 112 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 113 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 114 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 115 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 116 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 117 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 118 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 119 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 120 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 121 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 122 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 123 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 124 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# Taking image 125 of 125.
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
